# %% [markdown]
# # Query Template Demo

# %%
! cat src/configs/user_features/sql/silver_video_daily_rollup_agg_v2.yaml
# Out:
# template: rolling_aggregation_template
# template_fields:
#   partition_field: day
#   window_lengths: [7, 30, 60]
#   aggregations: [cumulative_sum, average]
#   window_type: day
#   join_key: adobe_tracking_id
#   features:
#     - android_device_seconds_played
#     - androidtv_device_seconds_played
#     - chromecast_device_seconds_played
#     - cox_device_seconds_played
#     - firetv_device_seconds_played
#     - ios_device_seconds_played
#     - lg_device_seconds_played
#     - playstation_device_seconds_played
#     - roku_device_seconds_played
#     - samsung_device_seconds_played
#     - tvos_device_seconds_played
#     - vidaa_device_seconds_played
#     - vizio_device_seconds_played
#     - web_device_seconds_played
#     - xbox_device_seconds_played
#     - xclass_device_seconds_played
#     - xfinity_x1_device_seconds_played
#     - action_adventure_genre_seconds_played
#     - comedy_genre_seconds_played
#     - crime_genre_seconds_played
#     - documentary_genre_seconds_played
#     - drama_genre_seconds_played
#     - horror_genre_seconds_played
#     - kids_genre_seconds_played
#     - mystery_suspense_genre_seconds_played
#     - na_genre_seconds_played
#     - news_genre_seconds_played
#     - reality_genre_seconds_played
#     - sci_fi_fantasy_genre_seconds_played
#     - thriller_genre_seconds_played
#     - tv_genre_seconds_played
#     - wwe_genre_seconds_played
#     - usa_track_field_genre_seconds_played
#     - sneak_peek_genre_seconds_played
#     - ski_jumping_genre_seconds_played
#     - world_rugby_seven_genre_seconds_played
#     - winter_sports_genre_seconds_played
#     - imsa_genre_seconds_played
#     - romance_genre_seconds_played
#     - tvg_genre_seconds_played
#     - bobsledding_genre_seconds_played
#     - lifestyle_genre_seconds_played
#     - indy_500_genre_seconds_played
#     - para_alpine_skiing_genre_seconds_played
#     - sports_genre_seconds_played
#     - football_genre_seconds_played
#     - mlb_genre_seconds_played
#     - gymnastics_genre_seconds_played
#     - horse_racing_genre_seconds_played
#     - movies_genre_seconds_played
#     - international_genre_seconds_played
#     - game_show_genre_seconds_played
#     - the_soccer_tournament_genre_seconds_played
#     - mystery_genre_seconds_played
#     - holiday_genre_seconds_played
#     - rugby_world_cup_genre_seconds_played
#     - wrestling_genre_seconds_played
#     - premier_league_genre_seconds_played
#     - ice_skating_genre_seconds_played
#     - track_field_genre_seconds_played
#     - speed_skating_genre_seconds_played
#     - military_war_genre_seconds_played
#     - musical_genre_seconds_played
#     - unknown_genre_seconds_played
#     - short_track_genre_seconds_played
#     - comedy_drama_genre_seconds_played
#     - nfl_genre_seconds_played
#     - tennis_genre_seconds_played
#     - ecw_genre_seconds_played
#     - live_205_genre_seconds_played
#     - latest_episode_genre_seconds_played
#     - cross_country_skiing_genre_seconds_played
#     - motor_sports_genre_seconds_played
#     - raw_genre_seconds_played
#     - nxt_uk_genre_seconds_played
#     - curling_genre_seconds_played
#     - diamond_league_genre_seconds_played
#     - ncaa_genre_seconds_played
#     - auto_racing_genre_seconds_played
#     - adventure_genre_seconds_played
#     - wcw_genre_seconds_played
#     - competition_genre_seconds_played
#     - martial_arts_genre_seconds_played
#     - indy_nxt_genre_seconds_played
#     - sled_hockey_genre_seconds_played
#     - indy_lights_genre_seconds_played
#     - talk_genre_seconds_played
#     - figure_skating_genre_seconds_played
#     - pro_wrestling_genre_seconds_played
#     - skeleton_genre_seconds_played
#     - nature_genre_seconds_played
#     - hockey_genre_seconds_played
#     - golf_genre_seconds_played
#     - music_genre_seconds_played
#     - supercross_genre_seconds_played
#     - travel_genre_seconds_played
#     - luge_genre_seconds_played
#     - weightlifting_genre_seconds_played
#     - biathlon_genre_seconds_played
#     - pro_motocross_genre_seconds_played
#     - college_hockey_genre_seconds_played
#     - tv14_genre_seconds_played
#     - variety_genre_seconds_played
#     - anime_genre_seconds_played
#     - cycling_genre_seconds_played
#     - food_genre_seconds_played
#     - baseball_genre_seconds_played
#     - entertainment_genre_seconds_played
#     - six_nations_genre_seconds_played
#     - health_fitness_genre_seconds_played
#     - swimming_genre_seconds_played
#     - game_show_contest_genre_seconds_played
#     - nxt_genre_seconds_played
#     - business_finance_genre_seconds_played
#     - cartoon_animation_genre_seconds_played
#     - premiership_rugby_genre_seconds_played
#     - fantasy_genre_seconds_played
#     - animation_genre_seconds_played
#     - science_technology_genre_seconds_played
#     - action_genre_seconds_played
#     - ceremony_genre_seconds_played
#     - snowboarding_genre_seconds_played
#     - history_biography_genre_seconds_played
#     - basketball_genre_seconds_played
#     - stand_up_comedy_genre_seconds_played
#     - soccer_genre_seconds_played
#     - nitro_rallycross_genre_seconds_played
#     - weathertech_series_genre_seconds_played
#     - boxing_genre_seconds_played
#     - para_biathlon_genre_seconds_played
#     - today_genre_seconds_played
#     - wheelchair_curling_genre_seconds_played
#     - olympics_genre_seconds_played
#     - freestyle_skiing_genre_seconds_played
#     - pga_genre_seconds_played
#     - world_athletics_genre_seconds_played
#     - western_genre_seconds_played
#     - ice_hockey_genre_seconds_played
#     - religion_genre_seconds_played
#     - para_snowboarding_genre_seconds_played
#     - rugby_genre_seconds_played
#     - ntt_indycar_series_genre_seconds_played
#     - smackdown_genre_seconds_played
#     - extreme_sports_genre_seconds_played
#     - sci_fi_genre_seconds_played
#     - animals_genre_seconds_played
#     - nordic_combined_genre_seconds_played
#     - nascar_genre_seconds_played
#     - tvpg_genre_seconds_played
#     - alpine_skiing_genre_seconds_played
#     - para_cc_skiing_genre_seconds_played
#     - college_football_genre_seconds_played
#     - indycar_genre_seconds_played
#     - usfl_genre_seconds_played
#     - paralympic_genre_seconds_played
#     - large_screen_seconds
#     - num_daily_sessions
#     - num_views_completed
#     - num_views_started
#     - num_views_reached_perc_25_perc
#     - num_views_reached_perc_50_perc
#     - num_views_reached_perc_75_perc
#     - small_screen_seconds
#   upstream_table: silver_video_daily_rollup_v2

# %%
from src.query_constructor.query_template import QueryTemplate


query_template: QueryTemplate = actions.get_query(
    query_name='silver_video_daily_rollup_agg_v2',
    environment_template_fields=actions.default_environment_template_fields(
        start_date='2023-01-01', table_name='silver_video_daily_rollup_agg_v2'
    ),
)

# %% [markdown]
# ## Render base case

# %%
print(query_template.render(run_day='2023-01-01'))
# Out:
# SELECT
#   DATE('2023-01-01') as day,
#   adobe_tracking_id,
#   cast(android_device_seconds_played AS FLOAT64) AS cumulative_sum_android_device_seconds_played_day_7,
#   cast(android_device_seconds_played AS FLOAT64) AS cumulative_sum_android_device_seconds_played_day_30,
#   cast(android_device_seconds_played AS FLOAT64) AS cumulative_sum_android_device_seconds_played_day_60,
#   cast(android_device_seconds_played as float64) AS average_android_device_seconds_played_day_7,
#   cast(android_device_seconds_played as float64) AS average_android_device_seconds_played_day_30,
#   cast(android_device_seconds_played as float64) AS average_android_device_seconds_played_day_60,
#   cast(androidtv_device_seconds_played AS FLOAT64) AS cumulative_sum_androidtv_device_seconds_played_day_7,
#   cast(androidtv_device_seconds_played AS FLOAT64) AS cumulative_sum_androidtv_device_seconds_played_day_30,
#   cast(androidtv_device_seconds_played AS FLOAT64) AS cumulative_sum_androidtv_device_seconds_played_day_60,
#   cast(androidtv_device_seconds_played as float64) AS average_androidtv_device_seconds_played_day_7,
#   cast(androidtv_device_seconds_played as float64) AS average_androidtv_device_seconds_played_day_30,
#   cast(androidtv_device_seconds_played as float64) AS average_androidtv_device_seconds_played_day_60,
#   cast(chromecast_device_seconds_played AS FLOAT64) AS cumulative_sum_chromecast_device_seconds_played_day_7,
#   cast(chromecast_device_seconds_played AS FLOAT64) AS cumulative_sum_chromecast_device_seconds_played_day_30,
#   cast(chromecast_device_seconds_played AS FLOAT64) AS cumulative_sum_chromecast_device_seconds_played_day_60,
#   cast(chromecast_device_seconds_played as float64) AS average_chromecast_device_seconds_played_day_7,
#   cast(chromecast_device_seconds_played as float64) AS average_chromecast_device_seconds_played_day_30,
#   cast(chromecast_device_seconds_played as float64) AS average_chromecast_device_seconds_played_day_60,
#   cast(cox_device_seconds_played AS FLOAT64) AS cumulative_sum_cox_device_seconds_played_day_7,
#   cast(cox_device_seconds_played AS FLOAT64) AS cumulative_sum_cox_device_seconds_played_day_30,
#   cast(cox_device_seconds_played AS FLOAT64) AS cumulative_sum_cox_device_seconds_played_day_60,
#   cast(cox_device_seconds_played as float64) AS average_cox_device_seconds_played_day_7,
#   cast(cox_device_seconds_played as float64) AS average_cox_device_seconds_played_day_30,
#   cast(cox_device_seconds_played as float64) AS average_cox_device_seconds_played_day_60,
#   cast(firetv_device_seconds_played AS FLOAT64) AS cumulative_sum_firetv_device_seconds_played_day_7,
#   cast(firetv_device_seconds_played AS FLOAT64) AS cumulative_sum_firetv_device_seconds_played_day_30,
#   cast(firetv_device_seconds_played AS FLOAT64) AS cumulative_sum_firetv_device_seconds_played_day_60,
#   cast(firetv_device_seconds_played as float64) AS average_firetv_device_seconds_played_day_7,
#   cast(firetv_device_seconds_played as float64) AS average_firetv_device_seconds_played_day_30,
#   cast(firetv_device_seconds_played as float64) AS average_firetv_device_seconds_played_day_60,
#   cast(ios_device_seconds_played AS FLOAT64) AS cumulative_sum_ios_device_seconds_played_day_7,
#   cast(ios_device_seconds_played AS FLOAT64) AS cumulative_sum_ios_device_seconds_played_day_30,
#   cast(ios_device_seconds_played AS FLOAT64) AS cumulative_sum_ios_device_seconds_played_day_60,
#   cast(ios_device_seconds_played as float64) AS average_ios_device_seconds_played_day_7,
#   cast(ios_device_seconds_played as float64) AS average_ios_device_seconds_played_day_30,
#   cast(ios_device_seconds_played as float64) AS average_ios_device_seconds_played_day_60,
#   cast(lg_device_seconds_played AS FLOAT64) AS cumulative_sum_lg_device_seconds_played_day_7,
#   cast(lg_device_seconds_played AS FLOAT64) AS cumulative_sum_lg_device_seconds_played_day_30,
#   cast(lg_device_seconds_played AS FLOAT64) AS cumulative_sum_lg_device_seconds_played_day_60,
#   cast(lg_device_seconds_played as float64) AS average_lg_device_seconds_played_day_7,
#   cast(lg_device_seconds_played as float64) AS average_lg_device_seconds_played_day_30,
#   cast(lg_device_seconds_played as float64) AS average_lg_device_seconds_played_day_60,
#   cast(playstation_device_seconds_played AS FLOAT64) AS cumulative_sum_playstation_device_seconds_played_day_7,
#   cast(playstation_device_seconds_played AS FLOAT64) AS cumulative_sum_playstation_device_seconds_played_day_30,
#   cast(playstation_device_seconds_played AS FLOAT64) AS cumulative_sum_playstation_device_seconds_played_day_60,
#   cast(playstation_device_seconds_played as float64) AS average_playstation_device_seconds_played_day_7,
#   cast(playstation_device_seconds_played as float64) AS average_playstation_device_seconds_played_day_30,
#   cast(playstation_device_seconds_played as float64) AS average_playstation_device_seconds_played_day_60,
#   cast(roku_device_seconds_played AS FLOAT64) AS cumulative_sum_roku_device_seconds_played_day_7,
#   cast(roku_device_seconds_played AS FLOAT64) AS cumulative_sum_roku_device_seconds_played_day_30,
#   cast(roku_device_seconds_played AS FLOAT64) AS cumulative_sum_roku_device_seconds_played_day_60,
#   cast(roku_device_seconds_played as float64) AS average_roku_device_seconds_played_day_7,
#   cast(roku_device_seconds_played as float64) AS average_roku_device_seconds_played_day_30,
#   cast(roku_device_seconds_played as float64) AS average_roku_device_seconds_played_day_60,
#   cast(samsung_device_seconds_played AS FLOAT64) AS cumulative_sum_samsung_device_seconds_played_day_7,
#   cast(samsung_device_seconds_played AS FLOAT64) AS cumulative_sum_samsung_device_seconds_played_day_30,
#   cast(samsung_device_seconds_played AS FLOAT64) AS cumulative_sum_samsung_device_seconds_played_day_60,
#   cast(samsung_device_seconds_played as float64) AS average_samsung_device_seconds_played_day_7,
#   cast(samsung_device_seconds_played as float64) AS average_samsung_device_seconds_played_day_30,
#   cast(samsung_device_seconds_played as float64) AS average_samsung_device_seconds_played_day_60,
#   cast(tvos_device_seconds_played AS FLOAT64) AS cumulative_sum_tvos_device_seconds_played_day_7,
#   cast(tvos_device_seconds_played AS FLOAT64) AS cumulative_sum_tvos_device_seconds_played_day_30,
#   cast(tvos_device_seconds_played AS FLOAT64) AS cumulative_sum_tvos_device_seconds_played_day_60,
#   cast(tvos_device_seconds_played as float64) AS average_tvos_device_seconds_played_day_7,
#   cast(tvos_device_seconds_played as float64) AS average_tvos_device_seconds_played_day_30,
#   cast(tvos_device_seconds_played as float64) AS average_tvos_device_seconds_played_day_60,
#   cast(vidaa_device_seconds_played AS FLOAT64) AS cumulative_sum_vidaa_device_seconds_played_day_7,
#   cast(vidaa_device_seconds_played AS FLOAT64) AS cumulative_sum_vidaa_device_seconds_played_day_30,
#   cast(vidaa_device_seconds_played AS FLOAT64) AS cumulative_sum_vidaa_device_seconds_played_day_60,
#   cast(vidaa_device_seconds_played as float64) AS average_vidaa_device_seconds_played_day_7,
#   cast(vidaa_device_seconds_played as float64) AS average_vidaa_device_seconds_played_day_30,
#   cast(vidaa_device_seconds_played as float64) AS average_vidaa_device_seconds_played_day_60,
#   cast(vizio_device_seconds_played AS FLOAT64) AS cumulative_sum_vizio_device_seconds_played_day_7,
#   cast(vizio_device_seconds_played AS FLOAT64) AS cumulative_sum_vizio_device_seconds_played_day_30,
#   cast(vizio_device_seconds_played AS FLOAT64) AS cumulative_sum_vizio_device_seconds_played_day_60,
#   cast(vizio_device_seconds_played as float64) AS average_vizio_device_seconds_played_day_7,
#   cast(vizio_device_seconds_played as float64) AS average_vizio_device_seconds_played_day_30,
#   cast(vizio_device_seconds_played as float64) AS average_vizio_device_seconds_played_day_60,
#   cast(web_device_seconds_played AS FLOAT64) AS cumulative_sum_web_device_seconds_played_day_7,
#   cast(web_device_seconds_played AS FLOAT64) AS cumulative_sum_web_device_seconds_played_day_30,
#   cast(web_device_seconds_played AS FLOAT64) AS cumulative_sum_web_device_seconds_played_day_60,
#   cast(web_device_seconds_played as float64) AS average_web_device_seconds_played_day_7,
#   cast(web_device_seconds_played as float64) AS average_web_device_seconds_played_day_30,
#   cast(web_device_seconds_played as float64) AS average_web_device_seconds_played_day_60,
#   cast(xbox_device_seconds_played AS FLOAT64) AS cumulative_sum_xbox_device_seconds_played_day_7,
#   cast(xbox_device_seconds_played AS FLOAT64) AS cumulative_sum_xbox_device_seconds_played_day_30,
#   cast(xbox_device_seconds_played AS FLOAT64) AS cumulative_sum_xbox_device_seconds_played_day_60,
#   cast(xbox_device_seconds_played as float64) AS average_xbox_device_seconds_played_day_7,
#   cast(xbox_device_seconds_played as float64) AS average_xbox_device_seconds_played_day_30,
#   cast(xbox_device_seconds_played as float64) AS average_xbox_device_seconds_played_day_60,
#   cast(xclass_device_seconds_played AS FLOAT64) AS cumulative_sum_xclass_device_seconds_played_day_7,
#   cast(xclass_device_seconds_played AS FLOAT64) AS cumulative_sum_xclass_device_seconds_played_day_30,
#   cast(xclass_device_seconds_played AS FLOAT64) AS cumulative_sum_xclass_device_seconds_played_day_60,
#   cast(xclass_device_seconds_played as float64) AS average_xclass_device_seconds_played_day_7,
#   cast(xclass_device_seconds_played as float64) AS average_xclass_device_seconds_played_day_30,
#   cast(xclass_device_seconds_played as float64) AS average_xclass_device_seconds_played_day_60,
#   cast(xfinity_x1_device_seconds_played AS FLOAT64) AS cumulative_sum_xfinity_x1_device_seconds_played_day_7,
#   cast(xfinity_x1_device_seconds_played AS FLOAT64) AS cumulative_sum_xfinity_x1_device_seconds_played_day_30,
#   cast(xfinity_x1_device_seconds_played AS FLOAT64) AS cumulative_sum_xfinity_x1_device_seconds_played_day_60,
#   cast(xfinity_x1_device_seconds_played as float64) AS average_xfinity_x1_device_seconds_played_day_7,
#   cast(xfinity_x1_device_seconds_played as float64) AS average_xfinity_x1_device_seconds_played_day_30,
#   cast(xfinity_x1_device_seconds_played as float64) AS average_xfinity_x1_device_seconds_played_day_60,
#   cast(action_adventure_genre_seconds_played AS FLOAT64) AS cumulative_sum_action_adventure_genre_seconds_played_day_7,
#   cast(action_adventure_genre_seconds_played AS FLOAT64) AS cumulative_sum_action_adventure_genre_seconds_played_day_30,
#   cast(action_adventure_genre_seconds_played AS FLOAT64) AS cumulative_sum_action_adventure_genre_seconds_played_day_60,
#   cast(action_adventure_genre_seconds_played as float64) AS average_action_adventure_genre_seconds_played_day_7,
#   cast(action_adventure_genre_seconds_played as float64) AS average_action_adventure_genre_seconds_played_day_30,
#   cast(action_adventure_genre_seconds_played as float64) AS average_action_adventure_genre_seconds_played_day_60,
#   cast(comedy_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_genre_seconds_played_day_7,
#   cast(comedy_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_genre_seconds_played_day_30,
#   cast(comedy_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_genre_seconds_played_day_60,
#   cast(comedy_genre_seconds_played as float64) AS average_comedy_genre_seconds_played_day_7,
#   cast(comedy_genre_seconds_played as float64) AS average_comedy_genre_seconds_played_day_30,
#   cast(comedy_genre_seconds_played as float64) AS average_comedy_genre_seconds_played_day_60,
#   cast(crime_genre_seconds_played AS FLOAT64) AS cumulative_sum_crime_genre_seconds_played_day_7,
#   cast(crime_genre_seconds_played AS FLOAT64) AS cumulative_sum_crime_genre_seconds_played_day_30,
#   cast(crime_genre_seconds_played AS FLOAT64) AS cumulative_sum_crime_genre_seconds_played_day_60,
#   cast(crime_genre_seconds_played as float64) AS average_crime_genre_seconds_played_day_7,
#   cast(crime_genre_seconds_played as float64) AS average_crime_genre_seconds_played_day_30,
#   cast(crime_genre_seconds_played as float64) AS average_crime_genre_seconds_played_day_60,
#   cast(documentary_genre_seconds_played AS FLOAT64) AS cumulative_sum_documentary_genre_seconds_played_day_7,
#   cast(documentary_genre_seconds_played AS FLOAT64) AS cumulative_sum_documentary_genre_seconds_played_day_30,
#   cast(documentary_genre_seconds_played AS FLOAT64) AS cumulative_sum_documentary_genre_seconds_played_day_60,
#   cast(documentary_genre_seconds_played as float64) AS average_documentary_genre_seconds_played_day_7,
#   cast(documentary_genre_seconds_played as float64) AS average_documentary_genre_seconds_played_day_30,
#   cast(documentary_genre_seconds_played as float64) AS average_documentary_genre_seconds_played_day_60,
#   cast(drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_drama_genre_seconds_played_day_7,
#   cast(drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_drama_genre_seconds_played_day_30,
#   cast(drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_drama_genre_seconds_played_day_60,
#   cast(drama_genre_seconds_played as float64) AS average_drama_genre_seconds_played_day_7,
#   cast(drama_genre_seconds_played as float64) AS average_drama_genre_seconds_played_day_30,
#   cast(drama_genre_seconds_played as float64) AS average_drama_genre_seconds_played_day_60,
#   cast(horror_genre_seconds_played AS FLOAT64) AS cumulative_sum_horror_genre_seconds_played_day_7,
#   cast(horror_genre_seconds_played AS FLOAT64) AS cumulative_sum_horror_genre_seconds_played_day_30,
#   cast(horror_genre_seconds_played AS FLOAT64) AS cumulative_sum_horror_genre_seconds_played_day_60,
#   cast(horror_genre_seconds_played as float64) AS average_horror_genre_seconds_played_day_7,
#   cast(horror_genre_seconds_played as float64) AS average_horror_genre_seconds_played_day_30,
#   cast(horror_genre_seconds_played as float64) AS average_horror_genre_seconds_played_day_60,
#   cast(kids_genre_seconds_played AS FLOAT64) AS cumulative_sum_kids_genre_seconds_played_day_7,
#   cast(kids_genre_seconds_played AS FLOAT64) AS cumulative_sum_kids_genre_seconds_played_day_30,
#   cast(kids_genre_seconds_played AS FLOAT64) AS cumulative_sum_kids_genre_seconds_played_day_60,
#   cast(kids_genre_seconds_played as float64) AS average_kids_genre_seconds_played_day_7,
#   cast(kids_genre_seconds_played as float64) AS average_kids_genre_seconds_played_day_30,
#   cast(kids_genre_seconds_played as float64) AS average_kids_genre_seconds_played_day_60,
#   cast(mystery_suspense_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_suspense_genre_seconds_played_day_7,
#   cast(mystery_suspense_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_suspense_genre_seconds_played_day_30,
#   cast(mystery_suspense_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_suspense_genre_seconds_played_day_60,
#   cast(mystery_suspense_genre_seconds_played as float64) AS average_mystery_suspense_genre_seconds_played_day_7,
#   cast(mystery_suspense_genre_seconds_played as float64) AS average_mystery_suspense_genre_seconds_played_day_30,
#   cast(mystery_suspense_genre_seconds_played as float64) AS average_mystery_suspense_genre_seconds_played_day_60,
#   cast(na_genre_seconds_played AS FLOAT64) AS cumulative_sum_na_genre_seconds_played_day_7,
#   cast(na_genre_seconds_played AS FLOAT64) AS cumulative_sum_na_genre_seconds_played_day_30,
#   cast(na_genre_seconds_played AS FLOAT64) AS cumulative_sum_na_genre_seconds_played_day_60,
#   cast(na_genre_seconds_played as float64) AS average_na_genre_seconds_played_day_7,
#   cast(na_genre_seconds_played as float64) AS average_na_genre_seconds_played_day_30,
#   cast(na_genre_seconds_played as float64) AS average_na_genre_seconds_played_day_60,
#   cast(news_genre_seconds_played AS FLOAT64) AS cumulative_sum_news_genre_seconds_played_day_7,
#   cast(news_genre_seconds_played AS FLOAT64) AS cumulative_sum_news_genre_seconds_played_day_30,
#   cast(news_genre_seconds_played AS FLOAT64) AS cumulative_sum_news_genre_seconds_played_day_60,
#   cast(news_genre_seconds_played as float64) AS average_news_genre_seconds_played_day_7,
#   cast(news_genre_seconds_played as float64) AS average_news_genre_seconds_played_day_30,
#   cast(news_genre_seconds_played as float64) AS average_news_genre_seconds_played_day_60,
#   cast(reality_genre_seconds_played AS FLOAT64) AS cumulative_sum_reality_genre_seconds_played_day_7,
#   cast(reality_genre_seconds_played AS FLOAT64) AS cumulative_sum_reality_genre_seconds_played_day_30,
#   cast(reality_genre_seconds_played AS FLOAT64) AS cumulative_sum_reality_genre_seconds_played_day_60,
#   cast(reality_genre_seconds_played as float64) AS average_reality_genre_seconds_played_day_7,
#   cast(reality_genre_seconds_played as float64) AS average_reality_genre_seconds_played_day_30,
#   cast(reality_genre_seconds_played as float64) AS average_reality_genre_seconds_played_day_60,
#   cast(sci_fi_fantasy_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_fantasy_genre_seconds_played_day_7,
#   cast(sci_fi_fantasy_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_fantasy_genre_seconds_played_day_30,
#   cast(sci_fi_fantasy_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_fantasy_genre_seconds_played_day_60,
#   cast(sci_fi_fantasy_genre_seconds_played as float64) AS average_sci_fi_fantasy_genre_seconds_played_day_7,
#   cast(sci_fi_fantasy_genre_seconds_played as float64) AS average_sci_fi_fantasy_genre_seconds_played_day_30,
#   cast(sci_fi_fantasy_genre_seconds_played as float64) AS average_sci_fi_fantasy_genre_seconds_played_day_60,
#   cast(thriller_genre_seconds_played AS FLOAT64) AS cumulative_sum_thriller_genre_seconds_played_day_7,
#   cast(thriller_genre_seconds_played AS FLOAT64) AS cumulative_sum_thriller_genre_seconds_played_day_30,
#   cast(thriller_genre_seconds_played AS FLOAT64) AS cumulative_sum_thriller_genre_seconds_played_day_60,
#   cast(thriller_genre_seconds_played as float64) AS average_thriller_genre_seconds_played_day_7,
#   cast(thriller_genre_seconds_played as float64) AS average_thriller_genre_seconds_played_day_30,
#   cast(thriller_genre_seconds_played as float64) AS average_thriller_genre_seconds_played_day_60,
#   cast(tv_genre_seconds_played AS FLOAT64) AS cumulative_sum_tv_genre_seconds_played_day_7,
#   cast(tv_genre_seconds_played AS FLOAT64) AS cumulative_sum_tv_genre_seconds_played_day_30,
#   cast(tv_genre_seconds_played AS FLOAT64) AS cumulative_sum_tv_genre_seconds_played_day_60,
#   cast(tv_genre_seconds_played as float64) AS average_tv_genre_seconds_played_day_7,
#   cast(tv_genre_seconds_played as float64) AS average_tv_genre_seconds_played_day_30,
#   cast(tv_genre_seconds_played as float64) AS average_tv_genre_seconds_played_day_60,
#   cast(wwe_genre_seconds_played AS FLOAT64) AS cumulative_sum_wwe_genre_seconds_played_day_7,
#   cast(wwe_genre_seconds_played AS FLOAT64) AS cumulative_sum_wwe_genre_seconds_played_day_30,
#   cast(wwe_genre_seconds_played AS FLOAT64) AS cumulative_sum_wwe_genre_seconds_played_day_60,
#   cast(wwe_genre_seconds_played as float64) AS average_wwe_genre_seconds_played_day_7,
#   cast(wwe_genre_seconds_played as float64) AS average_wwe_genre_seconds_played_day_30,
#   cast(wwe_genre_seconds_played as float64) AS average_wwe_genre_seconds_played_day_60,
#   cast(usa_track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_usa_track_field_genre_seconds_played_day_7,
#   cast(usa_track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_usa_track_field_genre_seconds_played_day_30,
#   cast(usa_track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_usa_track_field_genre_seconds_played_day_60,
#   cast(usa_track_field_genre_seconds_played as float64) AS average_usa_track_field_genre_seconds_played_day_7,
#   cast(usa_track_field_genre_seconds_played as float64) AS average_usa_track_field_genre_seconds_played_day_30,
#   cast(usa_track_field_genre_seconds_played as float64) AS average_usa_track_field_genre_seconds_played_day_60,
#   cast(sneak_peek_genre_seconds_played AS FLOAT64) AS cumulative_sum_sneak_peek_genre_seconds_played_day_7,
#   cast(sneak_peek_genre_seconds_played AS FLOAT64) AS cumulative_sum_sneak_peek_genre_seconds_played_day_30,
#   cast(sneak_peek_genre_seconds_played AS FLOAT64) AS cumulative_sum_sneak_peek_genre_seconds_played_day_60,
#   cast(sneak_peek_genre_seconds_played as float64) AS average_sneak_peek_genre_seconds_played_day_7,
#   cast(sneak_peek_genre_seconds_played as float64) AS average_sneak_peek_genre_seconds_played_day_30,
#   cast(sneak_peek_genre_seconds_played as float64) AS average_sneak_peek_genre_seconds_played_day_60,
#   cast(ski_jumping_genre_seconds_played AS FLOAT64) AS cumulative_sum_ski_jumping_genre_seconds_played_day_7,
#   cast(ski_jumping_genre_seconds_played AS FLOAT64) AS cumulative_sum_ski_jumping_genre_seconds_played_day_30,
#   cast(ski_jumping_genre_seconds_played AS FLOAT64) AS cumulative_sum_ski_jumping_genre_seconds_played_day_60,
#   cast(ski_jumping_genre_seconds_played as float64) AS average_ski_jumping_genre_seconds_played_day_7,
#   cast(ski_jumping_genre_seconds_played as float64) AS average_ski_jumping_genre_seconds_played_day_30,
#   cast(ski_jumping_genre_seconds_played as float64) AS average_ski_jumping_genre_seconds_played_day_60,
#   cast(world_rugby_seven_genre_seconds_played AS FLOAT64) AS cumulative_sum_world_rugby_seven_genre_seconds_played_day_7,
#   cast(world_rugby_seven_genre_seconds_played AS FLOAT64) AS cumulative_sum_world_rugby_seven_genre_seconds_played_day_30,
#   cast(world_rugby_seven_genre_seconds_played AS FLOAT64) AS cumulative_sum_world_rugby_seven_genre_seconds_played_day_60,
#   cast(world_rugby_seven_genre_seconds_played as float64) AS average_world_rugby_seven_genre_seconds_played_day_7,
#   cast(world_rugby_seven_genre_seconds_played as float64) AS average_world_rugby_seven_genre_seconds_played_day_30,
#   cast(world_rugby_seven_genre_seconds_played as float64) AS average_world_rugby_seven_genre_seconds_played_day_60,
#   cast(winter_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_winter_sports_genre_seconds_played_day_7,
#   cast(winter_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_winter_sports_genre_seconds_played_day_30,
#   cast(winter_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_winter_sports_genre_seconds_played_day_60,
#   cast(winter_sports_genre_seconds_played as float64) AS average_winter_sports_genre_seconds_played_day_7,
#   cast(winter_sports_genre_seconds_played as float64) AS average_winter_sports_genre_seconds_played_day_30,
#   cast(winter_sports_genre_seconds_played as float64) AS average_winter_sports_genre_seconds_played_day_60,
#   cast(imsa_genre_seconds_played AS FLOAT64) AS cumulative_sum_imsa_genre_seconds_played_day_7,
#   cast(imsa_genre_seconds_played AS FLOAT64) AS cumulative_sum_imsa_genre_seconds_played_day_30,
#   cast(imsa_genre_seconds_played AS FLOAT64) AS cumulative_sum_imsa_genre_seconds_played_day_60,
#   cast(imsa_genre_seconds_played as float64) AS average_imsa_genre_seconds_played_day_7,
#   cast(imsa_genre_seconds_played as float64) AS average_imsa_genre_seconds_played_day_30,
#   cast(imsa_genre_seconds_played as float64) AS average_imsa_genre_seconds_played_day_60,
#   cast(romance_genre_seconds_played AS FLOAT64) AS cumulative_sum_romance_genre_seconds_played_day_7,
#   cast(romance_genre_seconds_played AS FLOAT64) AS cumulative_sum_romance_genre_seconds_played_day_30,
#   cast(romance_genre_seconds_played AS FLOAT64) AS cumulative_sum_romance_genre_seconds_played_day_60,
#   cast(romance_genre_seconds_played as float64) AS average_romance_genre_seconds_played_day_7,
#   cast(romance_genre_seconds_played as float64) AS average_romance_genre_seconds_played_day_30,
#   cast(romance_genre_seconds_played as float64) AS average_romance_genre_seconds_played_day_60,
#   cast(tvg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvg_genre_seconds_played_day_7,
#   cast(tvg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvg_genre_seconds_played_day_30,
#   cast(tvg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvg_genre_seconds_played_day_60,
#   cast(tvg_genre_seconds_played as float64) AS average_tvg_genre_seconds_played_day_7,
#   cast(tvg_genre_seconds_played as float64) AS average_tvg_genre_seconds_played_day_30,
#   cast(tvg_genre_seconds_played as float64) AS average_tvg_genre_seconds_played_day_60,
#   cast(bobsledding_genre_seconds_played AS FLOAT64) AS cumulative_sum_bobsledding_genre_seconds_played_day_7,
#   cast(bobsledding_genre_seconds_played AS FLOAT64) AS cumulative_sum_bobsledding_genre_seconds_played_day_30,
#   cast(bobsledding_genre_seconds_played AS FLOAT64) AS cumulative_sum_bobsledding_genre_seconds_played_day_60,
#   cast(bobsledding_genre_seconds_played as float64) AS average_bobsledding_genre_seconds_played_day_7,
#   cast(bobsledding_genre_seconds_played as float64) AS average_bobsledding_genre_seconds_played_day_30,
#   cast(bobsledding_genre_seconds_played as float64) AS average_bobsledding_genre_seconds_played_day_60,
#   cast(lifestyle_genre_seconds_played AS FLOAT64) AS cumulative_sum_lifestyle_genre_seconds_played_day_7,
#   cast(lifestyle_genre_seconds_played AS FLOAT64) AS cumulative_sum_lifestyle_genre_seconds_played_day_30,
#   cast(lifestyle_genre_seconds_played AS FLOAT64) AS cumulative_sum_lifestyle_genre_seconds_played_day_60,
#   cast(lifestyle_genre_seconds_played as float64) AS average_lifestyle_genre_seconds_played_day_7,
#   cast(lifestyle_genre_seconds_played as float64) AS average_lifestyle_genre_seconds_played_day_30,
#   cast(lifestyle_genre_seconds_played as float64) AS average_lifestyle_genre_seconds_played_day_60,
#   cast(indy_500_genre_seconds_played AS FLOAT64) AS cumulative_sum_indy_500_genre_seconds_played_day_7,
#   cast(indy_500_genre_seconds_played AS FLOAT64) AS cumulative_sum_indy_500_genre_seconds_played_day_30,
#   cast(indy_500_genre_seconds_played AS FLOAT64) AS cumulative_sum_indy_500_genre_seconds_played_day_60,
#   cast(indy_500_genre_seconds_played as float64) AS average_indy_500_genre_seconds_played_day_7,
#   cast(indy_500_genre_seconds_played as float64) AS average_indy_500_genre_seconds_played_day_30,
#   cast(indy_500_genre_seconds_played as float64) AS average_indy_500_genre_seconds_played_day_60,
#   cast(para_alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_alpine_skiing_genre_seconds_played_day_7,
#   cast(para_alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_alpine_skiing_genre_seconds_played_day_30,
#   cast(para_alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_alpine_skiing_genre_seconds_played_day_60,
#   cast(para_alpine_skiing_genre_seconds_played as float64) AS average_para_alpine_skiing_genre_seconds_played_day_7,
#   cast(para_alpine_skiing_genre_seconds_played as float64) AS average_para_alpine_skiing_genre_seconds_played_day_30,
#   cast(para_alpine_skiing_genre_seconds_played as float64) AS average_para_alpine_skiing_genre_seconds_played_day_60,
#   cast(sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_sports_genre_seconds_played_day_7,
#   cast(sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_sports_genre_seconds_played_day_30,
#   cast(sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_sports_genre_seconds_played_day_60,
#   cast(sports_genre_seconds_played as float64) AS average_sports_genre_seconds_played_day_7,
#   cast(sports_genre_seconds_played as float64) AS average_sports_genre_seconds_played_day_30,
#   cast(sports_genre_seconds_played as float64) AS average_sports_genre_seconds_played_day_60,
#   cast(football_genre_seconds_played AS FLOAT64) AS cumulative_sum_football_genre_seconds_played_day_7,
#   cast(football_genre_seconds_played AS FLOAT64) AS cumulative_sum_football_genre_seconds_played_day_30,
#   cast(football_genre_seconds_played AS FLOAT64) AS cumulative_sum_football_genre_seconds_played_day_60,
#   cast(football_genre_seconds_played as float64) AS average_football_genre_seconds_played_day_7,
#   cast(football_genre_seconds_played as float64) AS average_football_genre_seconds_played_day_30,
#   cast(football_genre_seconds_played as float64) AS average_football_genre_seconds_played_day_60,
#   cast(mlb_genre_seconds_played AS FLOAT64) AS cumulative_sum_mlb_genre_seconds_played_day_7,
#   cast(mlb_genre_seconds_played AS FLOAT64) AS cumulative_sum_mlb_genre_seconds_played_day_30,
#   cast(mlb_genre_seconds_played AS FLOAT64) AS cumulative_sum_mlb_genre_seconds_played_day_60,
#   cast(mlb_genre_seconds_played as float64) AS average_mlb_genre_seconds_played_day_7,
#   cast(mlb_genre_seconds_played as float64) AS average_mlb_genre_seconds_played_day_30,
#   cast(mlb_genre_seconds_played as float64) AS average_mlb_genre_seconds_played_day_60,
#   cast(gymnastics_genre_seconds_played AS FLOAT64) AS cumulative_sum_gymnastics_genre_seconds_played_day_7,
#   cast(gymnastics_genre_seconds_played AS FLOAT64) AS cumulative_sum_gymnastics_genre_seconds_played_day_30,
#   cast(gymnastics_genre_seconds_played AS FLOAT64) AS cumulative_sum_gymnastics_genre_seconds_played_day_60,
#   cast(gymnastics_genre_seconds_played as float64) AS average_gymnastics_genre_seconds_played_day_7,
#   cast(gymnastics_genre_seconds_played as float64) AS average_gymnastics_genre_seconds_played_day_30,
#   cast(gymnastics_genre_seconds_played as float64) AS average_gymnastics_genre_seconds_played_day_60,
#   cast(horse_racing_genre_seconds_played AS FLOAT64) AS cumulative_sum_horse_racing_genre_seconds_played_day_7,
#   cast(horse_racing_genre_seconds_played AS FLOAT64) AS cumulative_sum_horse_racing_genre_seconds_played_day_30,
#   cast(horse_racing_genre_seconds_played AS FLOAT64) AS cumulative_sum_horse_racing_genre_seconds_played_day_60,
#   cast(horse_racing_genre_seconds_played as float64) AS average_horse_racing_genre_seconds_played_day_7,
#   cast(horse_racing_genre_seconds_played as float64) AS average_horse_racing_genre_seconds_played_day_30,
#   cast(horse_racing_genre_seconds_played as float64) AS average_horse_racing_genre_seconds_played_day_60,
#   cast(movies_genre_seconds_played AS FLOAT64) AS cumulative_sum_movies_genre_seconds_played_day_7,
#   cast(movies_genre_seconds_played AS FLOAT64) AS cumulative_sum_movies_genre_seconds_played_day_30,
#   cast(movies_genre_seconds_played AS FLOAT64) AS cumulative_sum_movies_genre_seconds_played_day_60,
#   cast(movies_genre_seconds_played as float64) AS average_movies_genre_seconds_played_day_7,
#   cast(movies_genre_seconds_played as float64) AS average_movies_genre_seconds_played_day_30,
#   cast(movies_genre_seconds_played as float64) AS average_movies_genre_seconds_played_day_60,
#   cast(international_genre_seconds_played AS FLOAT64) AS cumulative_sum_international_genre_seconds_played_day_7,
#   cast(international_genre_seconds_played AS FLOAT64) AS cumulative_sum_international_genre_seconds_played_day_30,
#   cast(international_genre_seconds_played AS FLOAT64) AS cumulative_sum_international_genre_seconds_played_day_60,
#   cast(international_genre_seconds_played as float64) AS average_international_genre_seconds_played_day_7,
#   cast(international_genre_seconds_played as float64) AS average_international_genre_seconds_played_day_30,
#   cast(international_genre_seconds_played as float64) AS average_international_genre_seconds_played_day_60,
#   cast(game_show_genre_seconds_played AS FLOAT64) AS cumulative_sum_game_show_genre_seconds_played_day_7,
#   cast(game_show_genre_seconds_played AS FLOAT64) AS cumulative_sum_game_show_genre_seconds_played_day_30,
#   cast(game_show_genre_seconds_played AS FLOAT64) AS cumulative_sum_game_show_genre_seconds_played_day_60,
#   cast(game_show_genre_seconds_played as float64) AS average_game_show_genre_seconds_played_day_7,
#   cast(game_show_genre_seconds_played as float64) AS average_game_show_genre_seconds_played_day_30,
#   cast(game_show_genre_seconds_played as float64) AS average_game_show_genre_seconds_played_day_60,
#   cast(the_soccer_tournament_genre_seconds_played AS FLOAT64) AS cumulative_sum_the_soccer_tournament_genre_seconds_played_day_7,
#   cast(the_soccer_tournament_genre_seconds_played AS FLOAT64) AS cumulative_sum_the_soccer_tournament_genre_seconds_played_day_30,
#   cast(the_soccer_tournament_genre_seconds_played AS FLOAT64) AS cumulative_sum_the_soccer_tournament_genre_seconds_played_day_60,
#   cast(the_soccer_tournament_genre_seconds_played as float64) AS average_the_soccer_tournament_genre_seconds_played_day_7,
#   cast(the_soccer_tournament_genre_seconds_played as float64) AS average_the_soccer_tournament_genre_seconds_played_day_30,
#   cast(the_soccer_tournament_genre_seconds_played as float64) AS average_the_soccer_tournament_genre_seconds_played_day_60,
#   cast(mystery_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_genre_seconds_played_day_7,
#   cast(mystery_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_genre_seconds_played_day_30,
#   cast(mystery_genre_seconds_played AS FLOAT64) AS cumulative_sum_mystery_genre_seconds_played_day_60,
#   cast(mystery_genre_seconds_played as float64) AS average_mystery_genre_seconds_played_day_7,
#   cast(mystery_genre_seconds_played as float64) AS average_mystery_genre_seconds_played_day_30,
#   cast(mystery_genre_seconds_played as float64) AS average_mystery_genre_seconds_played_day_60,
#   cast(holiday_genre_seconds_played AS FLOAT64) AS cumulative_sum_holiday_genre_seconds_played_day_7,
#   cast(holiday_genre_seconds_played AS FLOAT64) AS cumulative_sum_holiday_genre_seconds_played_day_30,
#   cast(holiday_genre_seconds_played AS FLOAT64) AS cumulative_sum_holiday_genre_seconds_played_day_60,
#   cast(holiday_genre_seconds_played as float64) AS average_holiday_genre_seconds_played_day_7,
#   cast(holiday_genre_seconds_played as float64) AS average_holiday_genre_seconds_played_day_30,
#   cast(holiday_genre_seconds_played as float64) AS average_holiday_genre_seconds_played_day_60,
#   cast(rugby_world_cup_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_world_cup_genre_seconds_played_day_7,
#   cast(rugby_world_cup_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_world_cup_genre_seconds_played_day_30,
#   cast(rugby_world_cup_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_world_cup_genre_seconds_played_day_60,
#   cast(rugby_world_cup_genre_seconds_played as float64) AS average_rugby_world_cup_genre_seconds_played_day_7,
#   cast(rugby_world_cup_genre_seconds_played as float64) AS average_rugby_world_cup_genre_seconds_played_day_30,
#   cast(rugby_world_cup_genre_seconds_played as float64) AS average_rugby_world_cup_genre_seconds_played_day_60,
#   cast(wrestling_genre_seconds_played AS FLOAT64) AS cumulative_sum_wrestling_genre_seconds_played_day_7,
#   cast(wrestling_genre_seconds_played AS FLOAT64) AS cumulative_sum_wrestling_genre_seconds_played_day_30,
#   cast(wrestling_genre_seconds_played AS FLOAT64) AS cumulative_sum_wrestling_genre_seconds_played_day_60,
#   cast(wrestling_genre_seconds_played as float64) AS average_wrestling_genre_seconds_played_day_7,
#   cast(wrestling_genre_seconds_played as float64) AS average_wrestling_genre_seconds_played_day_30,
#   cast(wrestling_genre_seconds_played as float64) AS average_wrestling_genre_seconds_played_day_60,
#   cast(premier_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_premier_league_genre_seconds_played_day_7,
#   cast(premier_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_premier_league_genre_seconds_played_day_30,
#   cast(premier_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_premier_league_genre_seconds_played_day_60,
#   cast(premier_league_genre_seconds_played as float64) AS average_premier_league_genre_seconds_played_day_7,
#   cast(premier_league_genre_seconds_played as float64) AS average_premier_league_genre_seconds_played_day_30,
#   cast(premier_league_genre_seconds_played as float64) AS average_premier_league_genre_seconds_played_day_60,
#   cast(ice_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_skating_genre_seconds_played_day_7,
#   cast(ice_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_skating_genre_seconds_played_day_30,
#   cast(ice_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_skating_genre_seconds_played_day_60,
#   cast(ice_skating_genre_seconds_played as float64) AS average_ice_skating_genre_seconds_played_day_7,
#   cast(ice_skating_genre_seconds_played as float64) AS average_ice_skating_genre_seconds_played_day_30,
#   cast(ice_skating_genre_seconds_played as float64) AS average_ice_skating_genre_seconds_played_day_60,
#   cast(track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_track_field_genre_seconds_played_day_7,
#   cast(track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_track_field_genre_seconds_played_day_30,
#   cast(track_field_genre_seconds_played AS FLOAT64) AS cumulative_sum_track_field_genre_seconds_played_day_60,
#   cast(track_field_genre_seconds_played as float64) AS average_track_field_genre_seconds_played_day_7,
#   cast(track_field_genre_seconds_played as float64) AS average_track_field_genre_seconds_played_day_30,
#   cast(track_field_genre_seconds_played as float64) AS average_track_field_genre_seconds_played_day_60,
#   cast(speed_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_speed_skating_genre_seconds_played_day_7,
#   cast(speed_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_speed_skating_genre_seconds_played_day_30,
#   cast(speed_skating_genre_seconds_played AS FLOAT64) AS cumulative_sum_speed_skating_genre_seconds_played_day_60,
#   cast(speed_skating_genre_seconds_played as float64) AS average_speed_skating_genre_seconds_played_day_7,
#   cast(speed_skating_genre_seconds_played as float64) AS average_speed_skating_genre_seconds_played_day_30,
#   cast(speed_skating_genre_seconds_played as float64) AS average_speed_skating_genre_seconds_played_day_60,
#   cast(military_war_genre_seconds_played AS FLOAT64) AS cumulative_sum_military_war_genre_seconds_played_day_7,
#   cast(military_war_genre_seconds_played AS FLOAT64) AS cumulative_sum_military_war_genre_seconds_played_day_30,
#   cast(military_war_genre_seconds_played AS FLOAT64) AS cumulative_sum_military_war_genre_seconds_played_day_60,
#   cast(military_war_genre_seconds_played as float64) AS average_military_war_genre_seconds_played_day_7,
#   cast(military_war_genre_seconds_played as float64) AS average_military_war_genre_seconds_played_day_30,
#   cast(military_war_genre_seconds_played as float64) AS average_military_war_genre_seconds_played_day_60,
#   cast(musical_genre_seconds_played AS FLOAT64) AS cumulative_sum_musical_genre_seconds_played_day_7,
#   cast(musical_genre_seconds_played AS FLOAT64) AS cumulative_sum_musical_genre_seconds_played_day_30,
#   cast(musical_genre_seconds_played AS FLOAT64) AS cumulative_sum_musical_genre_seconds_played_day_60,
#   cast(musical_genre_seconds_played as float64) AS average_musical_genre_seconds_played_day_7,
#   cast(musical_genre_seconds_played as float64) AS average_musical_genre_seconds_played_day_30,
#   cast(musical_genre_seconds_played as float64) AS average_musical_genre_seconds_played_day_60,
#   cast(unknown_genre_seconds_played AS FLOAT64) AS cumulative_sum_unknown_genre_seconds_played_day_7,
#   cast(unknown_genre_seconds_played AS FLOAT64) AS cumulative_sum_unknown_genre_seconds_played_day_30,
#   cast(unknown_genre_seconds_played AS FLOAT64) AS cumulative_sum_unknown_genre_seconds_played_day_60,
#   cast(unknown_genre_seconds_played as float64) AS average_unknown_genre_seconds_played_day_7,
#   cast(unknown_genre_seconds_played as float64) AS average_unknown_genre_seconds_played_day_30,
#   cast(unknown_genre_seconds_played as float64) AS average_unknown_genre_seconds_played_day_60,
#   cast(short_track_genre_seconds_played AS FLOAT64) AS cumulative_sum_short_track_genre_seconds_played_day_7,
#   cast(short_track_genre_seconds_played AS FLOAT64) AS cumulative_sum_short_track_genre_seconds_played_day_30,
#   cast(short_track_genre_seconds_played AS FLOAT64) AS cumulative_sum_short_track_genre_seconds_played_day_60,
#   cast(short_track_genre_seconds_played as float64) AS average_short_track_genre_seconds_played_day_7,
#   cast(short_track_genre_seconds_played as float64) AS average_short_track_genre_seconds_played_day_30,
#   cast(short_track_genre_seconds_played as float64) AS average_short_track_genre_seconds_played_day_60,
#   cast(comedy_drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_drama_genre_seconds_played_day_7,
#   cast(comedy_drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_drama_genre_seconds_played_day_30,
#   cast(comedy_drama_genre_seconds_played AS FLOAT64) AS cumulative_sum_comedy_drama_genre_seconds_played_day_60,
#   cast(comedy_drama_genre_seconds_played as float64) AS average_comedy_drama_genre_seconds_played_day_7,
#   cast(comedy_drama_genre_seconds_played as float64) AS average_comedy_drama_genre_seconds_played_day_30,
#   cast(comedy_drama_genre_seconds_played as float64) AS average_comedy_drama_genre_seconds_played_day_60,
#   cast(nfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_nfl_genre_seconds_played_day_7,
#   cast(nfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_nfl_genre_seconds_played_day_30,
#   cast(nfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_nfl_genre_seconds_played_day_60,
#   cast(nfl_genre_seconds_played as float64) AS average_nfl_genre_seconds_played_day_7,
#   cast(nfl_genre_seconds_played as float64) AS average_nfl_genre_seconds_played_day_30,
#   cast(nfl_genre_seconds_played as float64) AS average_nfl_genre_seconds_played_day_60,
#   cast(tennis_genre_seconds_played AS FLOAT64) AS cumulative_sum_tennis_genre_seconds_played_day_7,
#   cast(tennis_genre_seconds_played AS FLOAT64) AS cumulative_sum_tennis_genre_seconds_played_day_30,
#   cast(tennis_genre_seconds_played AS FLOAT64) AS cumulative_sum_tennis_genre_seconds_played_day_60,
#   cast(tennis_genre_seconds_played as float64) AS average_tennis_genre_seconds_played_day_7,
#   cast(tennis_genre_seconds_played as float64) AS average_tennis_genre_seconds_played_day_30,
#   cast(tennis_genre_seconds_played as float64) AS average_tennis_genre_seconds_played_day_60,
#   cast(ecw_genre_seconds_played AS FLOAT64) AS cumulative_sum_ecw_genre_seconds_played_day_7,
#   cast(ecw_genre_seconds_played AS FLOAT64) AS cumulative_sum_ecw_genre_seconds_played_day_30,
#   cast(ecw_genre_seconds_played AS FLOAT64) AS cumulative_sum_ecw_genre_seconds_played_day_60,
#   cast(ecw_genre_seconds_played as float64) AS average_ecw_genre_seconds_played_day_7,
#   cast(ecw_genre_seconds_played as float64) AS average_ecw_genre_seconds_played_day_30,
#   cast(ecw_genre_seconds_played as float64) AS average_ecw_genre_seconds_played_day_60,
#   cast(live_205_genre_seconds_played AS FLOAT64) AS cumulative_sum_live_205_genre_seconds_played_day_7,
#   cast(live_205_genre_seconds_played AS FLOAT64) AS cumulative_sum_live_205_genre_seconds_played_day_30,
#   cast(live_205_genre_seconds_played AS FLOAT64) AS cumulative_sum_live_205_genre_seconds_played_day_60,
#   cast(live_205_genre_seconds_played as float64) AS average_live_205_genre_seconds_played_day_7,
#   cast(live_205_genre_seconds_played as float64) AS average_live_205_genre_seconds_played_day_30,
#   cast(live_205_genre_seconds_played as float64) AS average_live_205_genre_seconds_played_day_60,
#   cast(latest_episode_genre_seconds_played AS FLOAT64) AS cumulative_sum_latest_episode_genre_seconds_played_day_7,
#   cast(latest_episode_genre_seconds_played AS FLOAT64) AS cumulative_sum_latest_episode_genre_seconds_played_day_30,
#   cast(latest_episode_genre_seconds_played AS FLOAT64) AS cumulative_sum_latest_episode_genre_seconds_played_day_60,
#   cast(latest_episode_genre_seconds_played as float64) AS average_latest_episode_genre_seconds_played_day_7,
#   cast(latest_episode_genre_seconds_played as float64) AS average_latest_episode_genre_seconds_played_day_30,
#   cast(latest_episode_genre_seconds_played as float64) AS average_latest_episode_genre_seconds_played_day_60,
#   cast(cross_country_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_cross_country_skiing_genre_seconds_played_day_7,
#   cast(cross_country_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_cross_country_skiing_genre_seconds_played_day_30,
#   cast(cross_country_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_cross_country_skiing_genre_seconds_played_day_60,
#   cast(cross_country_skiing_genre_seconds_played as float64) AS average_cross_country_skiing_genre_seconds_played_day_7,
#   cast(cross_country_skiing_genre_seconds_played as float64) AS average_cross_country_skiing_genre_seconds_played_day_30,
#   cast(cross_country_skiing_genre_seconds_played as float64) AS average_cross_country_skiing_genre_seconds_played_day_60,
#   cast(motor_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_motor_sports_genre_seconds_played_day_7,
#   cast(motor_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_motor_sports_genre_seconds_played_day_30,
#   cast(motor_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_motor_sports_genre_seconds_played_day_60,
#   cast(motor_sports_genre_seconds_played as float64) AS average_motor_sports_genre_seconds_played_day_7,
#   cast(motor_sports_genre_seconds_played as float64) AS average_motor_sports_genre_seconds_played_day_30,
#   cast(motor_sports_genre_seconds_played as float64) AS average_motor_sports_genre_seconds_played_day_60,
#   cast(raw_genre_seconds_played AS FLOAT64) AS cumulative_sum_raw_genre_seconds_played_day_7,
#   cast(raw_genre_seconds_played AS FLOAT64) AS cumulative_sum_raw_genre_seconds_played_day_30,
#   cast(raw_genre_seconds_played AS FLOAT64) AS cumulative_sum_raw_genre_seconds_played_day_60,
#   cast(raw_genre_seconds_played as float64) AS average_raw_genre_seconds_played_day_7,
#   cast(raw_genre_seconds_played as float64) AS average_raw_genre_seconds_played_day_30,
#   cast(raw_genre_seconds_played as float64) AS average_raw_genre_seconds_played_day_60,
#   cast(nxt_uk_genre_seconds_played AS FLOAT64) AS cumulative_sum_nxt_uk_genre_seconds_played_day_7,
#   cast(nxt_uk_genre_seconds_played AS FLOAT64) AS cumulative_sum_nxt_uk_genre_seconds_played_day_30,
#   cast(nxt_uk_genre_seconds_played AS FLOAT64) AS cumulative_sum_nxt_uk_genre_seconds_played_day_60,
#   cast(nxt_uk_genre_seconds_played as float64) AS average_nxt_uk_genre_seconds_played_day_7,
#   cast(nxt_uk_genre_seconds_played as float64) AS average_nxt_uk_genre_seconds_played_day_30,
#   cast(nxt_uk_genre_seconds_played as float64) AS average_nxt_uk_genre_seconds_played_day_60,
#   cast(curling_genre_seconds_played AS FLOAT64) AS cumulative_sum_curling_genre_seconds_played_day_7,
#   cast(curling_genre_seconds_played AS FLOAT64) AS cumulative_sum_curling_genre_seconds_played_day_30,
#   cast(curling_genre_seconds_played AS FLOAT64) AS cumulative_sum_curling_genre_seconds_played_day_60,
#   cast(curling_genre_seconds_played as float64) AS average_curling_genre_seconds_played_day_7,
#   cast(curling_genre_seconds_played as float64) AS average_curling_genre_seconds_played_day_30,
#   cast(curling_genre_seconds_played as float64) AS average_curling_genre_seconds_played_day_60,
#   cast(diamond_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_diamond_league_genre_seconds_played_day_7,
#   cast(diamond_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_diamond_league_genre_seconds_played_day_30,
#   cast(diamond_league_genre_seconds_played AS FLOAT64) AS cumulative_sum_diamond_league_genre_seconds_played_day_60,
#   cast(diamond_league_genre_seconds_played as float64) AS average_diamond_league_genre_seconds_played_day_7,
#   cast(diamond_league_genre_seconds_played as float64) AS average_diamond_league_genre_seconds_played_day_30,
#   cast(diamond_league_genre_seconds_played as float64) AS average_diamond_league_genre_seconds_played_day_60,
#   cast(ncaa_genre_seconds_played AS FLOAT64) AS cumulative_sum_ncaa_genre_seconds_played_day_7,
#   cast(ncaa_genre_seconds_played AS FLOAT64) AS cumulative_sum_ncaa_genre_seconds_played_day_30,
#   cast(ncaa_genre_seconds_played AS FLOAT64) AS cumulative_sum_ncaa_genre_seconds_played_day_60,
#   cast(ncaa_genre_seconds_played as float64) AS average_ncaa_genre_seconds_played_day_7,
#   cast(ncaa_genre_seconds_played as float64) AS average_ncaa_genre_seconds_played_day_30,
# ...
#   cast(western_genre_seconds_played as float64) AS average_western_genre_seconds_played_day_60,
#   cast(ice_hockey_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_hockey_genre_seconds_played_day_7,
#   cast(ice_hockey_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_hockey_genre_seconds_played_day_30,
#   cast(ice_hockey_genre_seconds_played AS FLOAT64) AS cumulative_sum_ice_hockey_genre_seconds_played_day_60,
#   cast(ice_hockey_genre_seconds_played as float64) AS average_ice_hockey_genre_seconds_played_day_7,
#   cast(ice_hockey_genre_seconds_played as float64) AS average_ice_hockey_genre_seconds_played_day_30,
#   cast(ice_hockey_genre_seconds_played as float64) AS average_ice_hockey_genre_seconds_played_day_60,
#   cast(religion_genre_seconds_played AS FLOAT64) AS cumulative_sum_religion_genre_seconds_played_day_7,
#   cast(religion_genre_seconds_played AS FLOAT64) AS cumulative_sum_religion_genre_seconds_played_day_30,
#   cast(religion_genre_seconds_played AS FLOAT64) AS cumulative_sum_religion_genre_seconds_played_day_60,
#   cast(religion_genre_seconds_played as float64) AS average_religion_genre_seconds_played_day_7,
#   cast(religion_genre_seconds_played as float64) AS average_religion_genre_seconds_played_day_30,
#   cast(religion_genre_seconds_played as float64) AS average_religion_genre_seconds_played_day_60,
#   cast(para_snowboarding_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_snowboarding_genre_seconds_played_day_7,
#   cast(para_snowboarding_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_snowboarding_genre_seconds_played_day_30,
#   cast(para_snowboarding_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_snowboarding_genre_seconds_played_day_60,
#   cast(para_snowboarding_genre_seconds_played as float64) AS average_para_snowboarding_genre_seconds_played_day_7,
#   cast(para_snowboarding_genre_seconds_played as float64) AS average_para_snowboarding_genre_seconds_played_day_30,
#   cast(para_snowboarding_genre_seconds_played as float64) AS average_para_snowboarding_genre_seconds_played_day_60,
#   cast(rugby_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_genre_seconds_played_day_7,
#   cast(rugby_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_genre_seconds_played_day_30,
#   cast(rugby_genre_seconds_played AS FLOAT64) AS cumulative_sum_rugby_genre_seconds_played_day_60,
#   cast(rugby_genre_seconds_played as float64) AS average_rugby_genre_seconds_played_day_7,
#   cast(rugby_genre_seconds_played as float64) AS average_rugby_genre_seconds_played_day_30,
#   cast(rugby_genre_seconds_played as float64) AS average_rugby_genre_seconds_played_day_60,
#   cast(ntt_indycar_series_genre_seconds_played AS FLOAT64) AS cumulative_sum_ntt_indycar_series_genre_seconds_played_day_7,
#   cast(ntt_indycar_series_genre_seconds_played AS FLOAT64) AS cumulative_sum_ntt_indycar_series_genre_seconds_played_day_30,
#   cast(ntt_indycar_series_genre_seconds_played AS FLOAT64) AS cumulative_sum_ntt_indycar_series_genre_seconds_played_day_60,
#   cast(ntt_indycar_series_genre_seconds_played as float64) AS average_ntt_indycar_series_genre_seconds_played_day_7,
#   cast(ntt_indycar_series_genre_seconds_played as float64) AS average_ntt_indycar_series_genre_seconds_played_day_30,
#   cast(ntt_indycar_series_genre_seconds_played as float64) AS average_ntt_indycar_series_genre_seconds_played_day_60,
#   cast(smackdown_genre_seconds_played AS FLOAT64) AS cumulative_sum_smackdown_genre_seconds_played_day_7,
#   cast(smackdown_genre_seconds_played AS FLOAT64) AS cumulative_sum_smackdown_genre_seconds_played_day_30,
#   cast(smackdown_genre_seconds_played AS FLOAT64) AS cumulative_sum_smackdown_genre_seconds_played_day_60,
#   cast(smackdown_genre_seconds_played as float64) AS average_smackdown_genre_seconds_played_day_7,
#   cast(smackdown_genre_seconds_played as float64) AS average_smackdown_genre_seconds_played_day_30,
#   cast(smackdown_genre_seconds_played as float64) AS average_smackdown_genre_seconds_played_day_60,
#   cast(extreme_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_extreme_sports_genre_seconds_played_day_7,
#   cast(extreme_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_extreme_sports_genre_seconds_played_day_30,
#   cast(extreme_sports_genre_seconds_played AS FLOAT64) AS cumulative_sum_extreme_sports_genre_seconds_played_day_60,
#   cast(extreme_sports_genre_seconds_played as float64) AS average_extreme_sports_genre_seconds_played_day_7,
#   cast(extreme_sports_genre_seconds_played as float64) AS average_extreme_sports_genre_seconds_played_day_30,
#   cast(extreme_sports_genre_seconds_played as float64) AS average_extreme_sports_genre_seconds_played_day_60,
#   cast(sci_fi_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_genre_seconds_played_day_7,
#   cast(sci_fi_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_genre_seconds_played_day_30,
#   cast(sci_fi_genre_seconds_played AS FLOAT64) AS cumulative_sum_sci_fi_genre_seconds_played_day_60,
#   cast(sci_fi_genre_seconds_played as float64) AS average_sci_fi_genre_seconds_played_day_7,
#   cast(sci_fi_genre_seconds_played as float64) AS average_sci_fi_genre_seconds_played_day_30,
#   cast(sci_fi_genre_seconds_played as float64) AS average_sci_fi_genre_seconds_played_day_60,
#   cast(animals_genre_seconds_played AS FLOAT64) AS cumulative_sum_animals_genre_seconds_played_day_7,
#   cast(animals_genre_seconds_played AS FLOAT64) AS cumulative_sum_animals_genre_seconds_played_day_30,
#   cast(animals_genre_seconds_played AS FLOAT64) AS cumulative_sum_animals_genre_seconds_played_day_60,
#   cast(animals_genre_seconds_played as float64) AS average_animals_genre_seconds_played_day_7,
#   cast(animals_genre_seconds_played as float64) AS average_animals_genre_seconds_played_day_30,
#   cast(animals_genre_seconds_played as float64) AS average_animals_genre_seconds_played_day_60,
#   cast(nordic_combined_genre_seconds_played AS FLOAT64) AS cumulative_sum_nordic_combined_genre_seconds_played_day_7,
#   cast(nordic_combined_genre_seconds_played AS FLOAT64) AS cumulative_sum_nordic_combined_genre_seconds_played_day_30,
#   cast(nordic_combined_genre_seconds_played AS FLOAT64) AS cumulative_sum_nordic_combined_genre_seconds_played_day_60,
#   cast(nordic_combined_genre_seconds_played as float64) AS average_nordic_combined_genre_seconds_played_day_7,
#   cast(nordic_combined_genre_seconds_played as float64) AS average_nordic_combined_genre_seconds_played_day_30,
#   cast(nordic_combined_genre_seconds_played as float64) AS average_nordic_combined_genre_seconds_played_day_60,
#   cast(nascar_genre_seconds_played AS FLOAT64) AS cumulative_sum_nascar_genre_seconds_played_day_7,
#   cast(nascar_genre_seconds_played AS FLOAT64) AS cumulative_sum_nascar_genre_seconds_played_day_30,
#   cast(nascar_genre_seconds_played AS FLOAT64) AS cumulative_sum_nascar_genre_seconds_played_day_60,
#   cast(nascar_genre_seconds_played as float64) AS average_nascar_genre_seconds_played_day_7,
#   cast(nascar_genre_seconds_played as float64) AS average_nascar_genre_seconds_played_day_30,
#   cast(nascar_genre_seconds_played as float64) AS average_nascar_genre_seconds_played_day_60,
#   cast(tvpg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvpg_genre_seconds_played_day_7,
#   cast(tvpg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvpg_genre_seconds_played_day_30,
#   cast(tvpg_genre_seconds_played AS FLOAT64) AS cumulative_sum_tvpg_genre_seconds_played_day_60,
#   cast(tvpg_genre_seconds_played as float64) AS average_tvpg_genre_seconds_played_day_7,
#   cast(tvpg_genre_seconds_played as float64) AS average_tvpg_genre_seconds_played_day_30,
#   cast(tvpg_genre_seconds_played as float64) AS average_tvpg_genre_seconds_played_day_60,
#   cast(alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_alpine_skiing_genre_seconds_played_day_7,
#   cast(alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_alpine_skiing_genre_seconds_played_day_30,
#   cast(alpine_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_alpine_skiing_genre_seconds_played_day_60,
#   cast(alpine_skiing_genre_seconds_played as float64) AS average_alpine_skiing_genre_seconds_played_day_7,
#   cast(alpine_skiing_genre_seconds_played as float64) AS average_alpine_skiing_genre_seconds_played_day_30,
#   cast(alpine_skiing_genre_seconds_played as float64) AS average_alpine_skiing_genre_seconds_played_day_60,
#   cast(para_cc_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_cc_skiing_genre_seconds_played_day_7,
#   cast(para_cc_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_cc_skiing_genre_seconds_played_day_30,
#   cast(para_cc_skiing_genre_seconds_played AS FLOAT64) AS cumulative_sum_para_cc_skiing_genre_seconds_played_day_60,
#   cast(para_cc_skiing_genre_seconds_played as float64) AS average_para_cc_skiing_genre_seconds_played_day_7,
#   cast(para_cc_skiing_genre_seconds_played as float64) AS average_para_cc_skiing_genre_seconds_played_day_30,
#   cast(para_cc_skiing_genre_seconds_played as float64) AS average_para_cc_skiing_genre_seconds_played_day_60,
#   cast(college_football_genre_seconds_played AS FLOAT64) AS cumulative_sum_college_football_genre_seconds_played_day_7,
#   cast(college_football_genre_seconds_played AS FLOAT64) AS cumulative_sum_college_football_genre_seconds_played_day_30,
#   cast(college_football_genre_seconds_played AS FLOAT64) AS cumulative_sum_college_football_genre_seconds_played_day_60,
#   cast(college_football_genre_seconds_played as float64) AS average_college_football_genre_seconds_played_day_7,
#   cast(college_football_genre_seconds_played as float64) AS average_college_football_genre_seconds_played_day_30,
#   cast(college_football_genre_seconds_played as float64) AS average_college_football_genre_seconds_played_day_60,
#   cast(indycar_genre_seconds_played AS FLOAT64) AS cumulative_sum_indycar_genre_seconds_played_day_7,
#   cast(indycar_genre_seconds_played AS FLOAT64) AS cumulative_sum_indycar_genre_seconds_played_day_30,
#   cast(indycar_genre_seconds_played AS FLOAT64) AS cumulative_sum_indycar_genre_seconds_played_day_60,
#   cast(indycar_genre_seconds_played as float64) AS average_indycar_genre_seconds_played_day_7,
#   cast(indycar_genre_seconds_played as float64) AS average_indycar_genre_seconds_played_day_30,
#   cast(indycar_genre_seconds_played as float64) AS average_indycar_genre_seconds_played_day_60,
#   cast(usfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_usfl_genre_seconds_played_day_7,
#   cast(usfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_usfl_genre_seconds_played_day_30,
#   cast(usfl_genre_seconds_played AS FLOAT64) AS cumulative_sum_usfl_genre_seconds_played_day_60,
#   cast(usfl_genre_seconds_played as float64) AS average_usfl_genre_seconds_played_day_7,
#   cast(usfl_genre_seconds_played as float64) AS average_usfl_genre_seconds_played_day_30,
#   cast(usfl_genre_seconds_played as float64) AS average_usfl_genre_seconds_played_day_60,
#   cast(paralympic_genre_seconds_played AS FLOAT64) AS cumulative_sum_paralympic_genre_seconds_played_day_7,
#   cast(paralympic_genre_seconds_played AS FLOAT64) AS cumulative_sum_paralympic_genre_seconds_played_day_30,
#   cast(paralympic_genre_seconds_played AS FLOAT64) AS cumulative_sum_paralympic_genre_seconds_played_day_60,
#   cast(paralympic_genre_seconds_played as float64) AS average_paralympic_genre_seconds_played_day_7,
#   cast(paralympic_genre_seconds_played as float64) AS average_paralympic_genre_seconds_played_day_30,
#   cast(paralympic_genre_seconds_played as float64) AS average_paralympic_genre_seconds_played_day_60,
#   cast(large_screen_seconds AS FLOAT64) AS cumulative_sum_large_screen_seconds_day_7,
#   cast(large_screen_seconds AS FLOAT64) AS cumulative_sum_large_screen_seconds_day_30,
#   cast(large_screen_seconds AS FLOAT64) AS cumulative_sum_large_screen_seconds_day_60,
#   cast(large_screen_seconds as float64) AS average_large_screen_seconds_day_7,
#   cast(large_screen_seconds as float64) AS average_large_screen_seconds_day_30,
#   cast(large_screen_seconds as float64) AS average_large_screen_seconds_day_60,
#   cast(num_daily_sessions AS FLOAT64) AS cumulative_sum_num_daily_sessions_day_7,
#   cast(num_daily_sessions AS FLOAT64) AS cumulative_sum_num_daily_sessions_day_30,
#   cast(num_daily_sessions AS FLOAT64) AS cumulative_sum_num_daily_sessions_day_60,
#   cast(num_daily_sessions as float64) AS average_num_daily_sessions_day_7,
#   cast(num_daily_sessions as float64) AS average_num_daily_sessions_day_30,
#   cast(num_daily_sessions as float64) AS average_num_daily_sessions_day_60,
#   cast(num_views_completed AS FLOAT64) AS cumulative_sum_num_views_completed_day_7,
#   cast(num_views_completed AS FLOAT64) AS cumulative_sum_num_views_completed_day_30,
#   cast(num_views_completed AS FLOAT64) AS cumulative_sum_num_views_completed_day_60,
#   cast(num_views_completed as float64) AS average_num_views_completed_day_7,
#   cast(num_views_completed as float64) AS average_num_views_completed_day_30,
#   cast(num_views_completed as float64) AS average_num_views_completed_day_60,
#   cast(num_views_started AS FLOAT64) AS cumulative_sum_num_views_started_day_7,
#   cast(num_views_started AS FLOAT64) AS cumulative_sum_num_views_started_day_30,
#   cast(num_views_started AS FLOAT64) AS cumulative_sum_num_views_started_day_60,
#   cast(num_views_started as float64) AS average_num_views_started_day_7,
#   cast(num_views_started as float64) AS average_num_views_started_day_30,
#   cast(num_views_started as float64) AS average_num_views_started_day_60,
#   cast(num_views_reached_perc_25_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_25_perc_day_7,
#   cast(num_views_reached_perc_25_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_25_perc_day_30,
#   cast(num_views_reached_perc_25_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_25_perc_day_60,
#   cast(num_views_reached_perc_25_perc as float64) AS average_num_views_reached_perc_25_perc_day_7,
#   cast(num_views_reached_perc_25_perc as float64) AS average_num_views_reached_perc_25_perc_day_30,
#   cast(num_views_reached_perc_25_perc as float64) AS average_num_views_reached_perc_25_perc_day_60,
#   cast(num_views_reached_perc_50_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_50_perc_day_7,
#   cast(num_views_reached_perc_50_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_50_perc_day_30,
#   cast(num_views_reached_perc_50_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_50_perc_day_60,
#   cast(num_views_reached_perc_50_perc as float64) AS average_num_views_reached_perc_50_perc_day_7,
#   cast(num_views_reached_perc_50_perc as float64) AS average_num_views_reached_perc_50_perc_day_30,
#   cast(num_views_reached_perc_50_perc as float64) AS average_num_views_reached_perc_50_perc_day_60,
#   cast(num_views_reached_perc_75_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_75_perc_day_7,
#   cast(num_views_reached_perc_75_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_75_perc_day_30,
#   cast(num_views_reached_perc_75_perc AS FLOAT64) AS cumulative_sum_num_views_reached_perc_75_perc_day_60,
#   cast(num_views_reached_perc_75_perc as float64) AS average_num_views_reached_perc_75_perc_day_7,
#   cast(num_views_reached_perc_75_perc as float64) AS average_num_views_reached_perc_75_perc_day_30,
#   cast(num_views_reached_perc_75_perc as float64) AS average_num_views_reached_perc_75_perc_day_60,
#   cast(small_screen_seconds AS FLOAT64) AS cumulative_sum_small_screen_seconds_day_7,
#   cast(small_screen_seconds AS FLOAT64) AS cumulative_sum_small_screen_seconds_day_30,
#   cast(small_screen_seconds AS FLOAT64) AS cumulative_sum_small_screen_seconds_day_60,
#   cast(small_screen_seconds as float64) AS average_small_screen_seconds_day_7,
#   cast(small_screen_seconds as float64) AS average_small_screen_seconds_day_30,
#   cast(small_screen_seconds as float64) AS average_small_screen_seconds_day_60,
# FROM
#   nbcu-ds-algo-int-001.algo_features.silver_video_daily_rollup_v2  as todays_data
# WHERE
#   day = '2023-01-01'
#   AND adobe_tracking_id IS NOT NULL

# %% [markdown]
# ## Render recursive case

# %%
print(query_template.render(run_day='2024-01-01'))
# Out:
# SELECT
#   DATE('2024-01-01') as day,
#   adobe_tracking_id,
# CASE
#   WHEN yesterdays_data.cumulative_sum_android_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_android_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.android_device_seconds_played
# END AS cumulative_sum_android_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_android_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_android_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.android_device_seconds_played
# END AS cumulative_sum_android_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_android_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_android_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.android_device_seconds_played
# END AS cumulative_sum_android_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_android_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.android_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.android_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.android_device_seconds_played
# END AS average_android_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_android_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.android_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.android_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.android_device_seconds_played
# END AS average_android_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_android_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.android_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.android_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.android_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_android_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.android_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.android_device_seconds_played
# END AS average_android_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.androidtv_device_seconds_played
# END AS cumulative_sum_androidtv_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.androidtv_device_seconds_played
# END AS cumulative_sum_androidtv_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_androidtv_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.androidtv_device_seconds_played
# END AS cumulative_sum_androidtv_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_androidtv_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.androidtv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.androidtv_device_seconds_played
# END AS average_androidtv_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_androidtv_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.androidtv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.androidtv_device_seconds_played
# END AS average_androidtv_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_androidtv_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.androidtv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.androidtv_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_androidtv_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.androidtv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.androidtv_device_seconds_played
# END AS average_androidtv_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.chromecast_device_seconds_played
# END AS cumulative_sum_chromecast_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.chromecast_device_seconds_played
# END AS cumulative_sum_chromecast_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_chromecast_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.chromecast_device_seconds_played
# END AS cumulative_sum_chromecast_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_chromecast_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.chromecast_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.chromecast_device_seconds_played
# END AS average_chromecast_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_chromecast_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.chromecast_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.chromecast_device_seconds_played
# END AS average_chromecast_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_chromecast_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.chromecast_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.chromecast_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_chromecast_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.chromecast_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.chromecast_device_seconds_played
# END AS average_chromecast_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_cox_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_cox_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.cox_device_seconds_played
# END AS cumulative_sum_cox_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_cox_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_cox_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.cox_device_seconds_played
# END AS cumulative_sum_cox_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_cox_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_cox_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.cox_device_seconds_played
# END AS cumulative_sum_cox_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_cox_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.cox_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.cox_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.cox_device_seconds_played
# END AS average_cox_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_cox_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.cox_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.cox_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.cox_device_seconds_played
# END AS average_cox_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_cox_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.cox_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.cox_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.cox_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_cox_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.cox_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.cox_device_seconds_played
# END AS average_cox_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.firetv_device_seconds_played
# END AS cumulative_sum_firetv_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.firetv_device_seconds_played
# END AS cumulative_sum_firetv_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_firetv_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.firetv_device_seconds_played
# END AS cumulative_sum_firetv_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_firetv_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.firetv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.firetv_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.firetv_device_seconds_played
# END AS average_firetv_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_firetv_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.firetv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.firetv_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.firetv_device_seconds_played
# END AS average_firetv_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_firetv_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.firetv_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.firetv_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.firetv_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_firetv_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.firetv_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.firetv_device_seconds_played
# END AS average_firetv_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_ios_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_ios_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.ios_device_seconds_played
# END AS cumulative_sum_ios_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_ios_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_ios_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.ios_device_seconds_played
# END AS cumulative_sum_ios_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_ios_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_ios_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.ios_device_seconds_played
# END AS cumulative_sum_ios_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_ios_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.ios_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.ios_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.ios_device_seconds_played
# END AS average_ios_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_ios_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.ios_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.ios_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.ios_device_seconds_played
# END AS average_ios_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_ios_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.ios_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.ios_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.ios_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_ios_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.ios_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.ios_device_seconds_played
# END AS average_ios_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_lg_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_lg_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.lg_device_seconds_played
# END AS cumulative_sum_lg_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_lg_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_lg_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.lg_device_seconds_played
# END AS cumulative_sum_lg_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_lg_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_lg_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.lg_device_seconds_played
# END AS cumulative_sum_lg_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_lg_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.lg_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.lg_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.lg_device_seconds_played
# END AS average_lg_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_lg_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.lg_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.lg_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.lg_device_seconds_played
# END AS average_lg_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_lg_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.lg_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.lg_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.lg_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_lg_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.lg_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.lg_device_seconds_played
# END AS average_lg_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.playstation_device_seconds_played
# END AS cumulative_sum_playstation_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.playstation_device_seconds_played
# END AS cumulative_sum_playstation_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_playstation_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.playstation_device_seconds_played
# END AS cumulative_sum_playstation_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_playstation_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.playstation_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.playstation_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.playstation_device_seconds_played
# END AS average_playstation_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_playstation_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.playstation_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.playstation_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.playstation_device_seconds_played
# END AS average_playstation_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_playstation_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.playstation_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.playstation_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.playstation_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_playstation_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.playstation_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.playstation_device_seconds_played
# END AS average_playstation_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_roku_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_roku_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.roku_device_seconds_played
# END AS cumulative_sum_roku_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_roku_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_roku_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.roku_device_seconds_played
# END AS cumulative_sum_roku_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_roku_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_roku_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.roku_device_seconds_played
# END AS cumulative_sum_roku_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_roku_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.roku_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.roku_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.roku_device_seconds_played
# END AS average_roku_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_roku_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.roku_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.roku_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.roku_device_seconds_played
# END AS average_roku_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_roku_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.roku_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.roku_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.roku_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_roku_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.roku_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.roku_device_seconds_played
# END AS average_roku_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.samsung_device_seconds_played
# END AS cumulative_sum_samsung_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.samsung_device_seconds_played
# END AS cumulative_sum_samsung_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_samsung_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.samsung_device_seconds_played
# END AS cumulative_sum_samsung_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_samsung_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.samsung_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.samsung_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.samsung_device_seconds_played
# END AS average_samsung_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_samsung_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.samsung_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.samsung_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.samsung_device_seconds_played
# END AS average_samsung_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_samsung_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.samsung_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.samsung_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.samsung_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_samsung_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.samsung_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.samsung_device_seconds_played
# END AS average_samsung_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.tvos_device_seconds_played
# END AS cumulative_sum_tvos_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.tvos_device_seconds_played
# END AS cumulative_sum_tvos_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_60 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_tvos_device_seconds_played_day_60, 0) -
#             IFNULL(previous_60_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.tvos_device_seconds_played
# END AS cumulative_sum_tvos_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.average_tvos_device_seconds_played_day_7 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             (7 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_7, 0)) -
#             IFNULL(previous_7_day.tvos_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 7 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.tvos_device_seconds_played, 0) +
#            (7 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_7, 0)) -
#            IFNULL(previous_7_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 7
#     END
#   ELSE todays_data.tvos_device_seconds_played
# END AS average_tvos_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.average_tvos_device_seconds_played_day_30 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             (30 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_30, 0)) -
#             IFNULL(previous_30_day.tvos_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 30 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.tvos_device_seconds_played, 0) +
#            (30 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_30, 0)) -
#            IFNULL(previous_30_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 30
#     END
#   ELSE todays_data.tvos_device_seconds_played
# END AS average_tvos_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.average_tvos_device_seconds_played_day_60 is not null
#     THEN
# CASE
#     WHEN ABS(CAST(
#       NULLIF(
#             (
#             IFNULL(todays_data.tvos_device_seconds_played, 0) +
#             (60 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_60, 0)) -
#             IFNULL(previous_60_day.tvos_device_seconds_played, 0)
#             ),
#             0
#            ) AS FLOAT64
#          ) / 60 )< 0.00001 THEN 0
#     ELSE
#       CAST(
#         NULLIF(
#           (
#            IFNULL(todays_data.tvos_device_seconds_played, 0) +
#            (60 * IFNULL(yesterdays_data.average_tvos_device_seconds_played_day_60, 0)) -
#            IFNULL(previous_60_day.tvos_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#       ) / 60
#     END
#   ELSE todays_data.tvos_device_seconds_played
# END AS average_tvos_device_seconds_played_day_60,
# CASE
#   WHEN yesterdays_data.cumulative_sum_vidaa_device_seconds_played_day_7 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.vidaa_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_vidaa_device_seconds_played_day_7, 0) -
#             IFNULL(previous_7_day.vidaa_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.vidaa_device_seconds_played
# END AS cumulative_sum_vidaa_device_seconds_played_day_7,
# CASE
#   WHEN yesterdays_data.cumulative_sum_vidaa_device_seconds_played_day_30 is not null
#     THEN
#       CAST(
#         NULLIF(
#           (
#             IFNULL(todays_data.vidaa_device_seconds_played, 0) +
#             IFNULL(yesterdays_data.cumulative_sum_vidaa_device_seconds_played_day_30, 0) -
#             IFNULL(previous_30_day.vidaa_device_seconds_played, 0)
#           ),
#           0
#         ) AS FLOAT64
#      )
#   ELSE todays_data.vidaa_device_seconds_played
# END AS cumulative_sum_vidaa_device_seconds_played_day_30,
# CASE
#   WHEN yesterdays_data.cumulative_sum_vidaa_device_seconds_played_day_60 is not null
#     THEN
# ...
#     latest_episode_genre_seconds_played,
#     cross_country_skiing_genre_seconds_played,
#     motor_sports_genre_seconds_played,
#     raw_genre_seconds_played,
#     nxt_uk_genre_seconds_played,
#     curling_genre_seconds_played,
#     diamond_league_genre_seconds_played,
#     ncaa_genre_seconds_played,
#     auto_racing_genre_seconds_played,
#     adventure_genre_seconds_played,
#     wcw_genre_seconds_played,
#     competition_genre_seconds_played,
#     martial_arts_genre_seconds_played,
#     indy_nxt_genre_seconds_played,
#     sled_hockey_genre_seconds_played,
#     indy_lights_genre_seconds_played,
#     talk_genre_seconds_played,
#     figure_skating_genre_seconds_played,
#     pro_wrestling_genre_seconds_played,
#     skeleton_genre_seconds_played,
#     nature_genre_seconds_played,
#     hockey_genre_seconds_played,
#     golf_genre_seconds_played,
#     music_genre_seconds_played,
#     supercross_genre_seconds_played,
#     travel_genre_seconds_played,
#     luge_genre_seconds_played,
#     weightlifting_genre_seconds_played,
#     biathlon_genre_seconds_played,
#     pro_motocross_genre_seconds_played,
#     college_hockey_genre_seconds_played,
#     tv14_genre_seconds_played,
#     variety_genre_seconds_played,
#     anime_genre_seconds_played,
#     cycling_genre_seconds_played,
#     food_genre_seconds_played,
#     baseball_genre_seconds_played,
#     entertainment_genre_seconds_played,
#     six_nations_genre_seconds_played,
#     health_fitness_genre_seconds_played,
#     swimming_genre_seconds_played,
#     game_show_contest_genre_seconds_played,
#     nxt_genre_seconds_played,
#     business_finance_genre_seconds_played,
#     cartoon_animation_genre_seconds_played,
#     premiership_rugby_genre_seconds_played,
#     fantasy_genre_seconds_played,
#     animation_genre_seconds_played,
#     science_technology_genre_seconds_played,
#     action_genre_seconds_played,
#     ceremony_genre_seconds_played,
#     snowboarding_genre_seconds_played,
#     history_biography_genre_seconds_played,
#     basketball_genre_seconds_played,
#     stand_up_comedy_genre_seconds_played,
#     soccer_genre_seconds_played,
#     nitro_rallycross_genre_seconds_played,
#     weathertech_series_genre_seconds_played,
#     boxing_genre_seconds_played,
#     para_biathlon_genre_seconds_played,
#     today_genre_seconds_played,
#     wheelchair_curling_genre_seconds_played,
#     olympics_genre_seconds_played,
#     freestyle_skiing_genre_seconds_played,
#     pga_genre_seconds_played,
#     world_athletics_genre_seconds_played,
#     western_genre_seconds_played,
#     ice_hockey_genre_seconds_played,
#     religion_genre_seconds_played,
#     para_snowboarding_genre_seconds_played,
#     rugby_genre_seconds_played,
#     ntt_indycar_series_genre_seconds_played,
#     smackdown_genre_seconds_played,
#     extreme_sports_genre_seconds_played,
#     sci_fi_genre_seconds_played,
#     animals_genre_seconds_played,
#     nordic_combined_genre_seconds_played,
#     nascar_genre_seconds_played,
#     tvpg_genre_seconds_played,
#     alpine_skiing_genre_seconds_played,
#     para_cc_skiing_genre_seconds_played,
#     college_football_genre_seconds_played,
#     indycar_genre_seconds_played,
#     usfl_genre_seconds_played,
#     paralympic_genre_seconds_played,
#     large_screen_seconds,
#     num_daily_sessions,
#     num_views_completed,
#     num_views_started,
#     num_views_reached_perc_25_perc,
#     num_views_reached_perc_50_perc,
#     num_views_reached_perc_75_perc,
#     small_screen_seconds,FROM
#     nbcu-ds-algo-int-001.algo_features.silver_video_daily_rollup_v2
#   WHERE
#     day = DATE_SUB('2024-01-01', INTERVAL 7 day)
# ) AS previous_7_day
# USING (adobe_tracking_id)
# FULL OUTER JOIN
# (
#   SELECT
#     adobe_tracking_id,
#     android_device_seconds_played,
#     androidtv_device_seconds_played,
#     chromecast_device_seconds_played,
#     cox_device_seconds_played,
#     firetv_device_seconds_played,
#     ios_device_seconds_played,
#     lg_device_seconds_played,
#     playstation_device_seconds_played,
#     roku_device_seconds_played,
#     samsung_device_seconds_played,
#     tvos_device_seconds_played,
#     vidaa_device_seconds_played,
#     vizio_device_seconds_played,
#     web_device_seconds_played,
#     xbox_device_seconds_played,
#     xclass_device_seconds_played,
#     xfinity_x1_device_seconds_played,
#     action_adventure_genre_seconds_played,
#     comedy_genre_seconds_played,
#     crime_genre_seconds_played,
#     documentary_genre_seconds_played,
#     drama_genre_seconds_played,
#     horror_genre_seconds_played,
#     kids_genre_seconds_played,
#     mystery_suspense_genre_seconds_played,
#     na_genre_seconds_played,
#     news_genre_seconds_played,
#     reality_genre_seconds_played,
#     sci_fi_fantasy_genre_seconds_played,
#     thriller_genre_seconds_played,
#     tv_genre_seconds_played,
#     wwe_genre_seconds_played,
#     usa_track_field_genre_seconds_played,
#     sneak_peek_genre_seconds_played,
#     ski_jumping_genre_seconds_played,
#     world_rugby_seven_genre_seconds_played,
#     winter_sports_genre_seconds_played,
#     imsa_genre_seconds_played,
#     romance_genre_seconds_played,
#     tvg_genre_seconds_played,
#     bobsledding_genre_seconds_played,
#     lifestyle_genre_seconds_played,
#     indy_500_genre_seconds_played,
#     para_alpine_skiing_genre_seconds_played,
#     sports_genre_seconds_played,
#     football_genre_seconds_played,
#     mlb_genre_seconds_played,
#     gymnastics_genre_seconds_played,
#     horse_racing_genre_seconds_played,
#     movies_genre_seconds_played,
#     international_genre_seconds_played,
#     game_show_genre_seconds_played,
#     the_soccer_tournament_genre_seconds_played,
#     mystery_genre_seconds_played,
#     holiday_genre_seconds_played,
#     rugby_world_cup_genre_seconds_played,
#     wrestling_genre_seconds_played,
#     premier_league_genre_seconds_played,
#     ice_skating_genre_seconds_played,
#     track_field_genre_seconds_played,
#     speed_skating_genre_seconds_played,
#     military_war_genre_seconds_played,
#     musical_genre_seconds_played,
#     unknown_genre_seconds_played,
#     short_track_genre_seconds_played,
#     comedy_drama_genre_seconds_played,
#     nfl_genre_seconds_played,
#     tennis_genre_seconds_played,
#     ecw_genre_seconds_played,
#     live_205_genre_seconds_played,
#     latest_episode_genre_seconds_played,
#     cross_country_skiing_genre_seconds_played,
#     motor_sports_genre_seconds_played,
#     raw_genre_seconds_played,
#     nxt_uk_genre_seconds_played,
#     curling_genre_seconds_played,
#     diamond_league_genre_seconds_played,
#     ncaa_genre_seconds_played,
#     auto_racing_genre_seconds_played,
#     adventure_genre_seconds_played,
#     wcw_genre_seconds_played,
#     competition_genre_seconds_played,
#     martial_arts_genre_seconds_played,
#     indy_nxt_genre_seconds_played,
#     sled_hockey_genre_seconds_played,
#     indy_lights_genre_seconds_played,
#     talk_genre_seconds_played,
#     figure_skating_genre_seconds_played,
#     pro_wrestling_genre_seconds_played,
#     skeleton_genre_seconds_played,
#     nature_genre_seconds_played,
#     hockey_genre_seconds_played,
#     golf_genre_seconds_played,
#     music_genre_seconds_played,
#     supercross_genre_seconds_played,
#     travel_genre_seconds_played,
#     luge_genre_seconds_played,
#     weightlifting_genre_seconds_played,
#     biathlon_genre_seconds_played,
#     pro_motocross_genre_seconds_played,
#     college_hockey_genre_seconds_played,
#     tv14_genre_seconds_played,
#     variety_genre_seconds_played,
#     anime_genre_seconds_played,
#     cycling_genre_seconds_played,
#     food_genre_seconds_played,
#     baseball_genre_seconds_played,
#     entertainment_genre_seconds_played,
#     six_nations_genre_seconds_played,
#     health_fitness_genre_seconds_played,
#     swimming_genre_seconds_played,
#     game_show_contest_genre_seconds_played,
#     nxt_genre_seconds_played,
#     business_finance_genre_seconds_played,
#     cartoon_animation_genre_seconds_played,
#     premiership_rugby_genre_seconds_played,
#     fantasy_genre_seconds_played,
#     animation_genre_seconds_played,
#     science_technology_genre_seconds_played,
#     action_genre_seconds_played,
#     ceremony_genre_seconds_played,
#     snowboarding_genre_seconds_played,
#     history_biography_genre_seconds_played,
#     basketball_genre_seconds_played,
#     stand_up_comedy_genre_seconds_played,
#     soccer_genre_seconds_played,
#     nitro_rallycross_genre_seconds_played,
#     weathertech_series_genre_seconds_played,
#     boxing_genre_seconds_played,
#     para_biathlon_genre_seconds_played,
#     today_genre_seconds_played,
#     wheelchair_curling_genre_seconds_played,
#     olympics_genre_seconds_played,
#     freestyle_skiing_genre_seconds_played,
#     pga_genre_seconds_played,
#     world_athletics_genre_seconds_played,
#     western_genre_seconds_played,
#     ice_hockey_genre_seconds_played,
#     religion_genre_seconds_played,
#     para_snowboarding_genre_seconds_played,
#     rugby_genre_seconds_played,
#     ntt_indycar_series_genre_seconds_played,
#     smackdown_genre_seconds_played,
#     extreme_sports_genre_seconds_played,
#     sci_fi_genre_seconds_played,
#     animals_genre_seconds_played,
#     nordic_combined_genre_seconds_played,
#     nascar_genre_seconds_played,
#     tvpg_genre_seconds_played,
#     alpine_skiing_genre_seconds_played,
#     para_cc_skiing_genre_seconds_played,
#     college_football_genre_seconds_played,
#     indycar_genre_seconds_played,
#     usfl_genre_seconds_played,
#     paralympic_genre_seconds_played,
#     large_screen_seconds,
#     num_daily_sessions,
#     num_views_completed,
#     num_views_started,
#     num_views_reached_perc_25_perc,
#     num_views_reached_perc_50_perc,
#     num_views_reached_perc_75_perc,
#     small_screen_seconds,FROM
#     nbcu-ds-algo-int-001.algo_features.silver_video_daily_rollup_v2
#   WHERE
#     day = DATE_SUB('2024-01-01', INTERVAL 30 day)
# ) AS previous_30_day
# USING (adobe_tracking_id)
# FULL OUTER JOIN
# (
#   SELECT
#     adobe_tracking_id,
#     android_device_seconds_played,
#     androidtv_device_seconds_played,
#     chromecast_device_seconds_played,
#     cox_device_seconds_played,
#     firetv_device_seconds_played,
#     ios_device_seconds_played,
#     lg_device_seconds_played,
#     playstation_device_seconds_played,
#     roku_device_seconds_played,
#     samsung_device_seconds_played,
#     tvos_device_seconds_played,
#     vidaa_device_seconds_played,
#     vizio_device_seconds_played,
#     web_device_seconds_played,
#     xbox_device_seconds_played,
#     xclass_device_seconds_played,
#     xfinity_x1_device_seconds_played,
#     action_adventure_genre_seconds_played,
#     comedy_genre_seconds_played,
#     crime_genre_seconds_played,
#     documentary_genre_seconds_played,
#     drama_genre_seconds_played,
#     horror_genre_seconds_played,
#     kids_genre_seconds_played,
#     mystery_suspense_genre_seconds_played,
#     na_genre_seconds_played,
#     news_genre_seconds_played,
#     reality_genre_seconds_played,
#     sci_fi_fantasy_genre_seconds_played,
#     thriller_genre_seconds_played,
#     tv_genre_seconds_played,
#     wwe_genre_seconds_played,
#     usa_track_field_genre_seconds_played,
#     sneak_peek_genre_seconds_played,
#     ski_jumping_genre_seconds_played,
#     world_rugby_seven_genre_seconds_played,
#     winter_sports_genre_seconds_played,
#     imsa_genre_seconds_played,
#     romance_genre_seconds_played,
#     tvg_genre_seconds_played,
#     bobsledding_genre_seconds_played,
#     lifestyle_genre_seconds_played,
#     indy_500_genre_seconds_played,
#     para_alpine_skiing_genre_seconds_played,
#     sports_genre_seconds_played,
#     football_genre_seconds_played,
#     mlb_genre_seconds_played,
#     gymnastics_genre_seconds_played,
#     horse_racing_genre_seconds_played,
#     movies_genre_seconds_played,
#     international_genre_seconds_played,
#     game_show_genre_seconds_played,
#     the_soccer_tournament_genre_seconds_played,
#     mystery_genre_seconds_played,
#     holiday_genre_seconds_played,
#     rugby_world_cup_genre_seconds_played,
#     wrestling_genre_seconds_played,
#     premier_league_genre_seconds_played,
#     ice_skating_genre_seconds_played,
#     track_field_genre_seconds_played,
#     speed_skating_genre_seconds_played,
#     military_war_genre_seconds_played,
#     musical_genre_seconds_played,
#     unknown_genre_seconds_played,
#     short_track_genre_seconds_played,
#     comedy_drama_genre_seconds_played,
#     nfl_genre_seconds_played,
#     tennis_genre_seconds_played,
#     ecw_genre_seconds_played,
#     live_205_genre_seconds_played,
#     latest_episode_genre_seconds_played,
#     cross_country_skiing_genre_seconds_played,
#     motor_sports_genre_seconds_played,
#     raw_genre_seconds_played,
#     nxt_uk_genre_seconds_played,
#     curling_genre_seconds_played,
#     diamond_league_genre_seconds_played,
#     ncaa_genre_seconds_played,
#     auto_racing_genre_seconds_played,
#     adventure_genre_seconds_played,
#     wcw_genre_seconds_played,
#     competition_genre_seconds_played,
#     martial_arts_genre_seconds_played,
#     indy_nxt_genre_seconds_played,
#     sled_hockey_genre_seconds_played,
#     indy_lights_genre_seconds_played,
#     talk_genre_seconds_played,
#     figure_skating_genre_seconds_played,
#     pro_wrestling_genre_seconds_played,
#     skeleton_genre_seconds_played,
#     nature_genre_seconds_played,
#     hockey_genre_seconds_played,
#     golf_genre_seconds_played,
#     music_genre_seconds_played,
#     supercross_genre_seconds_played,
#     travel_genre_seconds_played,
#     luge_genre_seconds_played,
#     weightlifting_genre_seconds_played,
#     biathlon_genre_seconds_played,
#     pro_motocross_genre_seconds_played,
#     college_hockey_genre_seconds_played,
#     tv14_genre_seconds_played,
#     variety_genre_seconds_played,
#     anime_genre_seconds_played,
#     cycling_genre_seconds_played,
#     food_genre_seconds_played,
#     baseball_genre_seconds_played,
#     entertainment_genre_seconds_played,
#     six_nations_genre_seconds_played,
#     health_fitness_genre_seconds_played,
#     swimming_genre_seconds_played,
#     game_show_contest_genre_seconds_played,
#     nxt_genre_seconds_played,
#     business_finance_genre_seconds_played,
#     cartoon_animation_genre_seconds_played,
#     premiership_rugby_genre_seconds_played,
#     fantasy_genre_seconds_played,
#     animation_genre_seconds_played,
#     science_technology_genre_seconds_played,
#     action_genre_seconds_played,
#     ceremony_genre_seconds_played,
#     snowboarding_genre_seconds_played,
#     history_biography_genre_seconds_played,
#     basketball_genre_seconds_played,
#     stand_up_comedy_genre_seconds_played,
#     soccer_genre_seconds_played,
#     nitro_rallycross_genre_seconds_played,
#     weathertech_series_genre_seconds_played,
#     boxing_genre_seconds_played,
#     para_biathlon_genre_seconds_played,
#     today_genre_seconds_played,
#     wheelchair_curling_genre_seconds_played,
#     olympics_genre_seconds_played,
#     freestyle_skiing_genre_seconds_played,
#     pga_genre_seconds_played,
#     world_athletics_genre_seconds_played,
#     western_genre_seconds_played,
#     ice_hockey_genre_seconds_played,
#     religion_genre_seconds_played,
#     para_snowboarding_genre_seconds_played,
#     rugby_genre_seconds_played,
#     ntt_indycar_series_genre_seconds_played,
#     smackdown_genre_seconds_played,
#     extreme_sports_genre_seconds_played,
#     sci_fi_genre_seconds_played,
#     animals_genre_seconds_played,
#     nordic_combined_genre_seconds_played,
#     nascar_genre_seconds_played,
#     tvpg_genre_seconds_played,
#     alpine_skiing_genre_seconds_played,
#     para_cc_skiing_genre_seconds_played,
#     college_football_genre_seconds_played,
#     indycar_genre_seconds_played,
#     usfl_genre_seconds_played,
#     paralympic_genre_seconds_played,
#     large_screen_seconds,
#     num_daily_sessions,
#     num_views_completed,
#     num_views_started,
#     num_views_reached_perc_25_perc,
#     num_views_reached_perc_50_perc,
#     num_views_reached_perc_75_perc,
#     small_screen_seconds,FROM
#     nbcu-ds-algo-int-001.algo_features.silver_video_daily_rollup_v2
#   WHERE
#     day = DATE_SUB('2024-01-01', INTERVAL 60 day)
# ) AS previous_60_day
# USING (adobe_tracking_id)
# FULL OUTER JOIN
# (
#   SELECT
#     *
#   FROM
#     nbcu-ds-algo-int-001.algo_features.silver_video_daily_rollup_agg_v2
#   WHERE
#     day = DATE_SUB(DATE('2024-01-01'), INTERVAL 1 day)
# ) AS yesterdays_data
#
# USING (adobe_tracking_id)
# WHERE adobe_tracking_id IS NOT NULL
